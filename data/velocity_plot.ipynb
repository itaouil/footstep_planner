# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read data
path = 'plot_0209.csv'
motion = np.genfromtxt(path, delimiter=',', dtype=np.float64)

# %%
motion.shape
# Out:
# (11069, 46)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = motion[5200:9500, 0]
s = motion[5200:9500, 1]
p = motion[5200:9500, 19]

# fig, ax = plt.subplots()
# ax.plot(t, s, p)

plt.plot(t, s, t, p)
plt.show()

# ax.set(xlabel='time (s)', ylabel='voltage (mV)',
#        title='About as simple as it gets, folks')
# ax.grid()

# fig.savefig("test.png")
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = motion[5200:9500, 0]
y1 = motion[5200:9500, 1]
y2 = motion[5200:9500, 19]

plt.plot(x, y1, "-b", label="                 ")
plt.plot(x, y2, "-r", label="                 ")
plt.legend(loc="upper left")
#plt.ylim(-1.5, 2.0)
plt.show()

# %%
p
# Out:
# array([0.17215174, 0.17215174, 0.17215174, ..., 0.09517711, 0.10554203,
#        0.10554203])
