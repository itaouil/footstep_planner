# %%
#!/usr/bin/env python3.6
# -*- coding: utf-8 -*-

# %%
# Imports
import sys
import math
import numpy as np
from matplotlib import animation
from IPython.display import HTML
from matplotlib import pyplot as plt
plt.rcParams['animation.ffmpeg_path'] = '/usr/bin/ffmpeg'
import mpl_toolkits.mplot3d.axes3d as p3

# %%
np.random.seed(20)
np.set_printoptions(threshold=sys.maxsize)

# %%
# %matplotlib inline

# %% [markdown]
# # Data

# %%
# Read data
path = '../../../dataset_real/gianpaolo/step_0.10/force/forward_accelerations.csv'
motion = np.genfromtxt(path, delimiter=',', dtype=np.float64)
contacts = np.genfromtxt(path, delimiter=',', usecols=(55, 56, 57, 58), dtype=bool)
print("Motion data has a length of ", len(motion))
# Out:
# Motion data has a length of  10257

# %%
print(motion.shape)
# Out:
# (10257, 59)

# %% [markdown]
# # Dataset Preparation

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
def yaw_from_quaternion(Q):
    """
    Covert a quaternion into a full three-dimensional rotation matrix.
 
    Input
    :param Q: A 4 element array representing the quaternion (q0,q1,q2,q3) 
 
    Output
    :return: A 3x3 element matrix representing the full 3D rotation matrix. 
             This rotation matrix converts a point in the local reference 
             frame to a point in the global reference frame.
    """
    # Extract the values from Q
    x = Q[0]
    y = Q[1]
    z = Q[2]
    w = Q[3]
     
    return np.arctan2(2 * (w*z + x*y), 1 - 2 * (y*y + z*z))

# %%
def quaternion_rotation_matrix(Q):
    """
    Covert a quaternion into a full three-dimensional rotation matrix.
 
    Input
    :param Q: A 4 element array representing the quaternion (q0,q1,q2,q3) 
 
    Output
    :return: A 3x3 element matrix representing the full 3D rotation matrix. 
             This rotation matrix converts a point in the local reference 
             frame to a point in the global reference frame.
    """
    # Extract the values from Q
    q0 = Q[3]
    q1 = Q[0]
    q2 = Q[1]
    q3 = Q[2]
     
    # First row of the rotation matrix
    r00 = 2 * (q0 * q0 + q1 * q1) - 1
    r01 = 2 * (q1 * q2 - q0 * q3)
    r02 = 2 * (q1 * q3 + q0 * q2)
     
    # Second row of the rotation matrix
    r10 = 2 * (q1 * q2 + q0 * q3)
    r11 = 2 * (q0 * q0 + q2 * q2) - 1
    r12 = 2 * (q2 * q3 - q0 * q1)
     
    # Third row of the rotation matrix
    r20 = 2 * (q1 * q3 - q0 * q2)
    r21 = 2 * (q2 * q3 + q0 * q1)
    r22 = 2 * (q0 * q0 + q3 * q3) - 1
     
    # 3x3 rotation matrix
    rot_matrix = np.array([[r00, r01, r02],
                           [r10, r11, r12],
                           [r20, r21, r22]])
                            
    return rot_matrix

# %%
def get_accelerations_footstep_dataset(dataset, footsteps, debug=False):
    # Footsteps sizes
    inputs = []
    labels = []
    
    for idx, footstep in enumerate(footsteps):
        if idx > 1:
            # Compute time difference between
            # curhent and next footsteps
            time_difference = abs(dataset[footsteps[idx], 0] - dataset[footsteps[idx-1], 0])

            if time_difference < 0.5 and (dataset[footsteps[idx-2], 1] > 0.05 or dataset[footsteps[idx-1], 1] > 0.05):
                lf_rh_moving = contacts[footsteps[idx], 0]
                rf_lh_moving = contacts[footsteps[idx], 1]
            
                if lf_rh_moving == rf_lh_moving:
                    idx += 1
                    continue

                # Compute rotation matrices from odometry orientation
                R_prev = quaternion_rotation_matrix(dataset[footsteps[idx-1], 48:52])
                R_curr = quaternion_rotation_matrix(dataset[footsteps[idx], 48:52])

                # Odom base vectors
                prev_base = dataset[footsteps[idx-1], 16:19]
                curr_base = dataset[footsteps[idx], 16:19]
                base_displacement = curr_base @ R_prev - prev_base @ R_prev
                
                prev_yaw = yaw_from_quaternion(dataset[footsteps[idx-1], 48:52])
                curr_yaw = yaw_from_quaternion(dataset[footsteps[idx], 48:52])
                yaw = curr_yaw - prev_yaw
                
                if abs(yaw) > 0.05:
                    continue
                
                inputs.append(dataset[footsteps[idx-2], 1:4].tolist() +
                              dataset[footsteps[idx-1], 1:16].tolist() +
                              dataset[footsteps[idx-1], 19:23].tolist() +
                              [lf_rh_moving, rf_lh_moving])
                    
                if lf_rh_moving:
                    # FL vectors
                    prev_fl = np.array([[dataset[footsteps[idx-1], 4], dataset[footsteps[idx-1], 5], 0]])
                    curr_fl = np.array([[dataset[footsteps[idx], 4], dataset[footsteps[idx], 5], 0]])

                    # RR vectors
                    prev_rr = np.array([[dataset[footsteps[idx-1], 13], dataset[footsteps[idx-1], 14], 0]])
                    curr_rr = np.array([[dataset[footsteps[idx], 13], dataset[footsteps[idx], 14], 0]])

                    # Feet displacements
                    fl_displacement = curr_fl - prev_fl + base_displacement
                    rr_displacement = curr_rr - prev_rr + base_displacement

                    labels.append([fl_displacement[0,0], fl_displacement[0,1], rr_displacement[0,0], rr_displacement[0,1]])
                else:
                    # FR vectors
                    prev_fr = np.array([[dataset[footsteps[idx-1], 7], dataset[footsteps[idx-1], 8], 0]])
                    curr_fr = np.array([[dataset[footsteps[idx], 7], dataset[footsteps[idx], 8], 0]])

                    # RL vectors
                    prev_rl = np.array([[dataset[footsteps[idx-1], 10], dataset[footsteps[idx-1], 11], 0]])
                    curr_rl = np.array([[dataset[footsteps[idx], 10], dataset[footsteps[idx], 11], 0]])

                    # Feet displacements
                    fr_displacement = curr_fr - prev_fr + base_displacement
                    rl_displacement = curr_rl - prev_rl + base_displacement

                    labels.append([fr_displacement[0,0], fr_displacement[0,1], rl_displacement[0,0], rl_displacement[0,1]])
                
                if (dataset[footsteps[idx-1], 1:4] == np.array([1.0, 0.0, 0.0])).all() and (dataset[footsteps[idx], 1:4] == np.array([0.1, 0.0, 0.0])).all():
                    print(labels[-1])
                    
    # Convert to numpy array
    inputs_numpy = np.array(inputs)
    labels_numpy = np.array(labels)
    
    return inputs_numpy, labels_numpy

# Stack datasets
X_footsteps_accelerations_absolute, Y_footsteps_accelerations_absolute = get_accelerations_footstep_dataset(motion, np.array([x for x in range(len(motion))]))

# Log
print(X_footsteps_accelerations_absolute.shape)
print(Y_footsteps_accelerations_absolute.shape)
# Out:
# (5750, 24)
# (5750, 4)

# %%
# %store X_footsteps_accelerations_absolute
# %store Y_footsteps_accelerations_absolute
# Out:
# Stored 'X_footsteps_accelerations_absolute' (ndarray)
# Stored 'Y_footsteps_accelerations_absolute' (ndarray)

# %%
for x in range(100):
    print(f"Prev vel: {X_footsteps_accelerations_absolute[x, 0]}. Actual Velocity: {X_footsteps_accelerations_absolute[x, 3]}. Step: {Y_footsteps_accelerations_absolute[x, :]}")
    print(f"CoM velocity: {X_footsteps_accelerations_absolute[x, 18]}\n")
# Out:
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [ 0.00347761  0.00614358  0.00682764 -0.00091188]
# CoM velocity: -0.0036863016430288553
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.03923992 -0.00250291  0.03669874 -0.00290027]
# CoM velocity: 0.011726198717951775
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.07283754 0.00763491 0.07142435 0.00148806]
# CoM velocity: 0.11857759952545166
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06864705 0.00177621 0.06717912 0.0034879 ]
# CoM velocity: 0.11840033531188965
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.05847757 -0.00068622  0.05752526  0.00038423]
# CoM velocity: 0.10101685672998428
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [ 0.04337089 -0.00154618  0.0445358   0.00091239]
# CoM velocity: 0.07741326838731766
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [ 0.03594808 -0.000366    0.03828364 -0.00364345]
# CoM velocity: 0.02660379745066166
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.07255322 0.00161268 0.0714855  0.00011324]
# CoM velocity: 0.11903909593820572
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.07031413 0.00413578 0.06629241 0.00354222]
# CoM velocity: 0.10799173265695572
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.06157493 -0.00207986  0.05966711 -0.00518917]
# CoM velocity: 0.11138002574443817
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [ 0.0538587  -0.00401257  0.05444244 -0.00113856]
# CoM velocity: 0.06800705939531326
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [ 0.03797837 -0.00240769  0.03876061 -0.00028394]
# CoM velocity: 0.010335729457437992
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.06896391  0.00203929  0.07049841 -0.00180093]
# CoM velocity: 0.10462473332881927
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06703464 0.00532253 0.06509446 0.00327317]
# CoM velocity: 0.11871273815631866
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 5.68094924e-02  6.89167614e-05  5.77167049e-02 -1.85713283e-03]
# CoM velocity: 0.1063576340675354
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.047251    0.00079116  0.04887551 -0.00249864]
# CoM velocity: 0.08080042898654938
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.05347127 0.00607501 0.05231023 0.00329035]
# CoM velocity: 0.10471315681934357
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [0.01939441 0.00595074 0.01994148 0.00330584]
# CoM velocity: 0.06781187653541565
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [-0.00025411 -0.00505222  0.00148304 -0.00646508]
# CoM velocity: -0.005354222375899553
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.02476673 0.00126622 0.02585123 0.00415149]
# CoM velocity: 7.7718315878883e-05
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.06207458 -0.00062555  0.05966123  0.00175907]
# CoM velocity: 0.08799689263105392
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 7.49075986e-02 -1.00599797e-03  7.20640994e-02 -7.78269909e-05]
# CoM velocity: 0.11798154562711716
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.0623974  0.00084711 0.06395788 0.00112072]
# CoM velocity: 0.10576417297124863
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.04606551 -0.00168057  0.04696639 -0.00074366]
# CoM velocity: 0.08993686735630035
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [ 0.01617609 -0.00184347  0.01515824  0.00026005]
# CoM velocity: 0.05637923255562782
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [-0.00085655  0.00193711 -0.00287634 -0.00173628]
# CoM velocity: -0.02215481735765934
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.02985241  0.00010559  0.02984951 -0.00205819]
# CoM velocity: 0.020304765552282333
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.0566418  0.00463686 0.05675495 0.00153804]
# CoM velocity: 0.07722736150026321
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.07000403  0.00287039  0.06814348 -0.00076807]
# CoM velocity: 0.11425177752971649
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06267842 0.00207528 0.06279954 0.00139264]
# CoM velocity: 0.10752014070749283
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.05334181  0.0021833   0.05193495 -0.00134928]
# CoM velocity: 0.10873514413833618
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [0.01708179 0.00248894 0.01620039 0.00190572]
# CoM velocity: 0.05479475483298302
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [-0.00095255  0.00113644 -0.00163544  0.00424819]
# CoM velocity: -0.03352880850434303
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.03032706  0.00224281  0.02942378 -0.00062455]
# CoM velocity: 0.02265203930437565
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.0690146  -0.00333411  0.06774882 -0.00156102]
# CoM velocity: 0.09391401708126068
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.07450864  0.00050209  0.07275285 -0.00026182]
# CoM velocity: 0.13672418892383575
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [6.67093269e-02 6.48873107e-06 6.39521948e-02 2.84382628e-03]
# CoM velocity: 0.10855243355035782
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.05220238 -0.00131946  0.05214219 -0.00289028]
# CoM velocity: 0.10638651996850967
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [ 0.0378687  -0.00093955  0.03892791  0.0023035 ]
# CoM velocity: 0.07330643385648727
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [ 0.02569889 -0.00062922  0.02802307  0.00059393]
# CoM velocity: -0.00472842063754797
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 5.87265650e-02  5.15536824e-03  5.95509420e-02 -4.73572900e-05]
# CoM velocity: 0.10505306720733643
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06501199 0.00092315 0.0616971  0.00189406]
# CoM velocity: 0.098855160176754
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06497164 0.00270509 0.06536408 0.00030262]
# CoM velocity: 0.11420142650604248
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [0.04527954 0.00140155 0.04539866 0.00037259]
# CoM velocity: 0.10062846541404724
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [ 2.29613979e-03  5.86547913e-05  2.29259332e-03 -2.51774108e-03]
# CoM velocity: -0.010315029881894588
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.02891163  0.00274795  0.02990782 -0.0006936 ]
# CoM velocity: 0.03409465402364731
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06533413 0.00329057 0.06589691 0.00089514]
# CoM velocity: 0.11241202801465988
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.069299   0.00198189 0.06759332 0.00585587]
# CoM velocity: 0.12347660213708878
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.06046245 -0.00023418  0.05825475 -0.00087727]
# CoM velocity: 0.11588843166828156
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.04783328 -0.00172571  0.0472653   0.0002197 ]
# CoM velocity: 0.0888064056634903
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [ 0.01632229 -0.00064138  0.01502426 -0.00116352]
# CoM velocity: 0.05870404839515686
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [ 0.00555453 -0.00324476  0.00501142 -0.00093177]
# CoM velocity: 0.0017081612022593617
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.03613268 -0.00184567  0.03455517  0.00017463]
# CoM velocity: 0.018977785483002663
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06652271 0.00484536 0.06617298 0.00194005]
# CoM velocity: 0.10754106938838959
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06869993 0.00457023 0.06781351 0.00132384]
# CoM velocity: 0.12141816318035126
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06030349 0.00048646 0.05801682 0.00031524]
# CoM velocity: 0.11823111772537231
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [ 0.04990131 -0.00247337  0.0522509  -0.00018008]
# CoM velocity: 0.0913684144616127
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [ 0.03253048 -0.00143131  0.03415707  0.00089893]
# CoM velocity: 0.015785710886120796
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06924475 0.00454617 0.06729872 0.00081225]
# CoM velocity: 0.09354327619075775
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.06172458 0.00563844 0.06089261 0.00377089]
# CoM velocity: 0.12298987060785294
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.05502906 -0.00014779  0.05211407 -0.00202947]
# CoM velocity: 0.09943564981222153
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [4.96742493e-02 6.02646066e-05 5.17192847e-02 1.88449456e-03]
# CoM velocity: 0.09360092133283615
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [0.04790383 0.00028934 0.04753665 0.00448564]
# CoM velocity: 0.11166340112686157
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [0.00252703 0.00325962 0.00284189 0.00361018]
# CoM velocity: -0.011667906306684017
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.03423246  0.00317373  0.03415592 -0.00096887]
# CoM velocity: 0.03604967147111893
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 6.46025118e-02 -2.87130555e-03  6.37009021e-02 -8.78505961e-05]
# CoM velocity: 0.10322104394435883
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.06610557 -0.00473559  0.06677996 -0.00180682]
# CoM velocity: 0.14090271294116974
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.06252574 -0.00014357  0.06149437  0.00080082]
# CoM velocity: 0.09606166929006577
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [0.05615171 0.00604923 0.05317967 0.00291986]
# CoM velocity: 0.1185280904173851
#
# Prev vel: 0.0. Actual Velocity: 0.1. Step: [-0.00351036  0.00295958 -0.00149078  0.00200377]
# CoM velocity: -0.020789165049791336
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [0.0297885  0.00269077 0.03145998 0.00206929]
# CoM velocity: 0.019549544900655746
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.0659801  -0.00243732  0.06478607 -0.00180039]
# CoM velocity: 0.08491651713848114
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.07346473 -0.00326586  0.07093329 -0.00422026]
# CoM velocity: 0.12779682874679565
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 0.06253057 -0.00135589  0.0616052   0.00376535]
# CoM velocity: 0.09303294122219086
#
# Prev vel: 0.1. Actual Velocity: 0.1. Step: [ 6.01033367e-02 -2.33683449e-04  5.93044258e-02 -8.89484704e-05]
# CoM velocity: 0.09922090172767639
#
# Prev vel: 0.1. Actual Velocity: 0.0. Step: [ 0.05295894  0.00189737  0.05127195 -0.00198574]
# CoM velocity: 0.08297410607337952
#
# Prev vel: 0.0. Actual Velocity: 0.2. Step: [ 0.0055256  -0.00863879  0.00466043 -0.00545904]
# CoM velocity: -2.4687673430889845e-05
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [ 0.06690061 -0.00172758  0.0652131  -0.0016638 ]
# CoM velocity: 0.04320289567112923
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.13588995 0.0035793  0.13669579 0.0021865 ]
# CoM velocity: 0.22153785824775696
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.14112175 0.00753915 0.13935085 0.01060294]
# CoM velocity: 0.2384723424911499
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.13104062 0.0078441  0.12973762 0.00485586]
# CoM velocity: 0.22777165472507477
#
# Prev vel: 0.2. Actual Velocity: 0.0. Step: [ 0.10610176 -0.00073562  0.10887475 -0.00113572]
# CoM velocity: 0.2233159989118576
#
# Prev vel: 0.0. Actual Velocity: 0.2. Step: [ 0.00308966 -0.00338078  0.0036804  -0.00455621]
# CoM velocity: -0.005458053667098284
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [ 0.06869783 -0.00574723  0.07241066 -0.00323321]
# CoM velocity: 0.050933822989463806
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.14303516 0.00865388 0.14217294 0.00348338]
# CoM velocity: 0.23417939245700836
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.14579185 0.00400769 0.1391642  0.00675402]
# CoM velocity: 0.2611633241176605
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.12379853 0.00345311 0.12295555 0.00092198]
# CoM velocity: 0.2397659420967102
#
# Prev vel: 0.2. Actual Velocity: 0.0. Step: [ 0.09622406  0.00017293  0.09786958 -0.00038021]
# CoM velocity: 0.18969306349754333
#
# Prev vel: 0.0. Actual Velocity: 0.2. Step: [ 0.00023966 -0.00548767 -0.00043241 -0.00603376]
# CoM velocity: -0.014243855141103268
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [ 0.06947228 -0.00110151  0.0714315  -0.00064475]
# CoM velocity: 0.047985974699258804
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.14154694 0.00636123 0.13974454 0.00225575]
# CoM velocity: 0.22336876392364502
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.14800273 0.00451524 0.14185113 0.01068326]
# CoM velocity: 0.2415083944797516
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.13133919 0.00595994 0.13324111 0.00088718]
# CoM velocity: 0.23045134544372559
#
# Prev vel: 0.2. Actual Velocity: 0.0. Step: [ 0.10756856 -0.0033644   0.11185651 -0.00154068]
# CoM velocity: 0.2239273637533188
#
# Prev vel: 0.0. Actual Velocity: 0.2. Step: [ 0.00805123 -0.00256296  0.00791394 -0.00559711]
# CoM velocity: -0.016486460343003273
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [ 0.06723615  0.00020587  0.0639276  -0.00144108]
# CoM velocity: 0.056414563208818436
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.14262169 0.00570132 0.14249629 0.00185506]
# CoM velocity: 0.22076141834259033
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.1457619  0.00960847 0.14254144 0.01185701]
# CoM velocity: 0.2678288221359253
#
# Prev vel: 0.2. Actual Velocity: 0.2. Step: [0.12217921 0.00361441 0.12157214 0.00052476]
# CoM velocity: 0.2250838279724121
#
# Prev vel: 0.2. Actual Velocity: 0.0. Step: [ 0.10136614 -0.00062645  0.10306062  0.001733  ]
# CoM velocity: 0.20035876333713531
