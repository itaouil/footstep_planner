# %%
#!/usr/bin/env python3.6
# -*- coding: utf-8 -*-

# %%
# Imports
import sys
import joblib
import numpy as np
from matplotlib import animation
from IPython.display import HTML
from matplotlib import pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3

# %%
#np.random.seed(20)
np.set_printoptions(threshold=sys.maxsize)

# %%
# %matplotlib inline

# %%
# %store -r X_motion_relative
# %store -r Y_motion_relative
print(X_motion_relative.shape)
print(Y_motion_relative.shape)
# Out:
# (27032, 27)
# (27032, 8)

# %% [markdown]
# # Multivariate Linear Regression (Foot prediction)

# %% [markdown]
# The input will use initially only:
#
# - **HighCmd: fwd, side, rot speeds**
# - **HighState: fwd, side, rot speeds, footPosition2Body (FR)**
#
# and as output we seek to predict the following:
#
# - **footPosition2Body (FR)**

# %%
import sklearn
from sklearn import metrics
from sklearn.feature_selection import RFE
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Entries where FL/RR are swinging
idxs = np.where(X_motion_relative[:, 25] == 1)[0]
X_motion_relative_FL_RR = X_motion_relative[idxs]
Y_motion_relative_FL_RR = Y_motion_relative[idxs]

# %% [markdown]
# ## Predict FL foot -> x

# %%
X_motion_relative_FL_RR.shape
# Out:
# (13320, 27)

# %%
X_motion_relative_FL_RR[0, :]
# Out:
# array([ 1.00000000e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  7.67128601e-27,  1.56430903e-26,
#         7.73122404e-03,  9.99970114e-01,  2.02702748e-04,  1.18196215e-04,
#         1.73000000e-01,  1.36000000e-01, -3.40000000e-01,  2.06000000e-01,
#        -1.35000000e-01, -3.39000000e-01, -2.68000000e-01,  1.36000000e-01,
#        -3.40000000e-01, -2.92000000e-01, -1.36000000e-01, -3.40000000e-01,
#         0.00000000e+00,  1.00000000e+00,  1.63241605e+09])

# %%
Y_motion_relative_FL_RR[0, :]
# Out:
# array([ 0.029, -0.004, -0.027, -0.002, -0.025,  0.001,  0.02 , -0.001])

# %% [markdown]
# ### Linear Regression

# %%
# Input
#X = np.hstack((X_motion_relative_FL_RR[:, :2], np.array([X_motion_relative_FL_RR[:, 5]]).T,
#               X_motion_relative_FL_RR[:, 6:8], np.array([X_motion_relative_FL_RR[:, 11]]).T,
#               np.array([X_motion_relative_FL_RR[:, 12]]).T, np.array([X_motion_relative_FL_RR[:, 15]]).T))
#X = np.hstack((X_motion_relative_FL_RR[:, :2], np.array([X_motion_relative_FL_RR[:, 5]]).T,
#               np.array([X_motion_relative_FL_RR[:, 12]]).T, np.array([X_motion_relative_FL_RR[:, 15]]).T))
X = np.hstack((X_motion_relative_FL_RR[:, :2],
               np.array([X_motion_relative_FL_RR[:, 5]]).T,
               X_motion_relative_FL_RR[:, 12:14],
               X_motion_relative_FL_RR[:, 15:17],
               X_motion_relative_FL_RR[:, 18:20],
               X_motion_relative_FL_RR[:, 21:23]))

# Target
Y = np.array([Y_motion_relative_FL_RR[:, 6]]).T

assert Y.shape[0] == X.shape[0]

# Split data into train and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.8, test_size=0.2, shuffle=True, random_state=100)

# Create the model
model_rr_relative_swinging_x = LinearRegression()

# Fit the model
model_rr_relative_swinging_x.fit(X_train, Y_train)

# Predict
predictions = model_rr_relative_swinging_x.predict(X_test)

# Stats
print('R2: ', r2_score(predictions, Y_test))
print('RMSE: ', np.sqrt(mean_squared_error(Y_test, predictions)))
print("The lowest error is: ", np.min(np.abs(predictions - Y_test)))
print("The highest error is: ", np.max(np.abs(predictions - Y_test)))
print("The avg. error is: ", np.mean(np.abs(predictions - Y_test)))
#print("Seq of errors (descendant): \n", sorted(np.abs(predictions - Y_test).tolist(), reverse=True))
# Out:
# R2:  0.9932230180587514
# RMSE:  0.004358757414409975
# The lowest error is:  6.595140696202817e-07
# The highest error is:  0.04699374180098059
# The avg. error is:  0.0021211262184737375

# %%
model_rr_relative_swinging_x.coef_
# Out:
# array([[ 5.92483902e-02,  5.98820152e-04,  3.74287507e-03,
#         -2.71333921e-01, -1.55467217e-01,  1.02390882e-01,
#          1.85833887e-01,  2.11099138e-01, -1.34491619e-01,
#         -8.86573251e-01,  1.74333171e-01]])

# %%
model_rr_relative_swinging_x.intercept_
# Out:
# array([-0.07321299])

# %%
## The line / model
plt.scatter(Y_test, predictions)
plt.xlabel("Ground truth")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# %store model_rr_relative_swinging_x
# Out:
# Stored 'model_rr_relative_swinging_x' (LinearRegression)

# %%
#for idx, prediction in enumerate(predictions):
#    print(f'Start: {X_test[idx, 6]}. Groundtruth: {Y_test[idx]}. Predicted: {prediction}')

# %%
# Save model
joblib.dump(model_rr_relative_swinging_x, "/home/itaouil/workspace/aliengo_ws/src/aliengo_navigation/models/protocol3/relative/model_rr_relative_swinging_x.sav")
# Out:
# ['/home/itaouil/workspace/aliengo_ws/src/aliengo_navigation/models/protocol3/relative/model_rr_relative_swinging_x.sav']

# %% [markdown]
# ### Predict FL foot -> y

# %%
# Input
#X = np.hstack((X_motion_relative_FL_RR[:, :2], np.array([X_motion_relative_FL_RR[:, 5]]).T,
#               X_motion_relative_FL_RR[:, 6:8], np.array([X_motion_relative_FL_RR[:, 11]]).T,
#               np.array([X_motion_relative_FL_RR[:, 12]]).T, np.array([X_motion_relative_FL_RR[:, 15]]).T))
#X = np.hstack((X_motion_relative_FL_RR[:, :2], np.array([X_motion_relative_FL_RR[:, 5]]).T,
#               np.array([X_motion_relative_FL_RR[:, 12]]).T, np.array([X_motion_relative_FL_RR[:, 15]]).T))
X = np.hstack((X_motion_relative_FL_RR[:, :2],
               np.array([X_motion_relative_FL_RR[:, 5]]).T,
               X_motion_relative_FL_RR[:, 12:14],
               X_motion_relative_FL_RR[:, 15:17],
               X_motion_relative_FL_RR[:, 18:20],
               X_motion_relative_FL_RR[:, 21:23]))
# Target
Y = np.array([Y_motion_relative_FL_RR[:, 7]]).T

assert Y.shape[0] == X.shape[0]

# Split data into train and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.8, shuffle=True, random_state=100)

# Create the model
model_rr_relative_swinging_y = LinearRegression()

# Fit the model
model_rr_relative_swinging_y.fit(X_train, Y_train)

# Predict
predictions = model_rr_relative_swinging_y.predict(X_test)

# Stats
print('R2: ', r2_score(predictions, Y_test))
print('RMSE: ', np.sqrt(mean_squared_error(Y_test, predictions)))
print("The lowest error is: ", np.min(np.abs(predictions - Y_test)))
print("The highest error is: ", np.max(np.abs(predictions - Y_test)))
print("The avg. error is: ", np.mean(np.abs(predictions - Y_test)))
#print("Seq of errors (descendant): \n", sorted(np.abs(predictions - Y_test).tolist(), reverse=True))
# Out:
# R2:  0.9949790409939085
# RMSE:  0.003763883068595202
# The lowest error is:  1.8206576893053938e-06
# The highest error is:  0.029424499693570846
# The avg. error is:  0.002538774191326812

# %%
model_rr_relative_swinging_y.coef_
# Out:
# array([[ 9.11557581e-04,  7.96752491e-03, -6.12761024e-03,
#         -1.69531771e-01, -3.69152908e-02, -8.70984474e-02,
#          1.09659174e-01,  7.69277098e-02,  3.90956364e-01,
#          1.45873682e-01, -1.22612609e+00]])

# %%
model_rr_relative_swinging_y.intercept_
# Out:
# array([-0.09027069])

# %%
## The line / model
plt.scatter(Y_test, predictions)
plt.xlabel("Ground truth")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# %store model_rr_relative_swinging_y
# Out:
# Stored 'model_rr_relative_swinging_y' (LinearRegression)

# %%
input_ = np.array([[0.  ,0.,    -0.6,    0.183,  0.153,  0.18,  -0.147, -0.277,  0.155, -0.268,
 -0.16, 1]])
print(input_.shape)
# Out:
# (1, 12)

# %%
coeff = np.array([[ 9.11557581e-04,  7.96752491e-03, -6.12761024e-03,
        -1.69531771e-01, -3.69152908e-02, -8.70984474e-02,
         1.09659174e-01,  7.69277098e-02,  3.90956364e-01,
         1.45873682e-01, -1.22612609e+00, model_rr_relative_swinging_y.i]])
print(coeff.shape)
# Out:
# (1, 12)

# %%
np.dot(input_, coeff.T)
# Out:
# array([[1.13158188]])

# %%
for idx, prediction in enumerate(predictions):
    print(f'Input: {X_test[idx]}. Groundtruth: {Y_test[idx]}. Predicted: {prediction}')
# Out:
# Input: [ 0.     0.    -0.6    0.183  0.153  0.18  -0.147 -0.277  0.155 -0.268
#  -0.16 ]. Groundtruth: [0.037]. Predicted: [0.04131119]
# Input: [ 0.7    0.     0.     0.103  0.142  0.275 -0.136 -0.201  0.135 -0.356
#  -0.14 ]. Groundtruth: [0.005]. Predicted: [0.0058412]
# Input: [ 0.         -0.3         0.          0.19954579  0.18478185  0.19232212
#  -0.17824467 -0.28185517  0.09327966 -0.28236407 -0.09570976]. Groundtruth: [-0.08063067]. Predicted: [-0.07866015]
# Input: [ 0.     0.     0.2    0.197  0.128  0.192 -0.129 -0.29   0.131 -0.285
#  -0.123]. Groundtruth: [-0.024]. Predicted: [-0.02234231]
# Input: [ 0.     0.    -0.6    0.182  0.153  0.18  -0.146 -0.278  0.154 -0.268
#  -0.161]. Groundtruth: [0.042]. Predicted: [0.04234862]
# Input: [ 0.     0.    -0.4    0.182  0.153  0.18  -0.145 -0.279  0.153 -0.268
#  -0.161]. Groundtruth: [0.042]. Predicted: [0.04076488]
# Input: [ 0.     0.     0.5    0.2    0.126  0.196 -0.12  -0.297  0.117 -0.288
#  -0.117]. Groundtruth: [-0.036]. Predicted: [-0.03778308]
# Input: [ 0.     0.    -0.7    0.18   0.154  0.18  -0.145 -0.28   0.153 -0.268
#  -0.163]. Groundtruth: [0.047]. Predicted: [0.04528063]
# Input: [ 0.7    0.     0.     0.074  0.139  0.255 -0.136 -0.222  0.137 -0.392
#  -0.137]. Groundtruth: [0.002]. Predicted: [0.00284693]
# Input: [ 0.     0.    -0.4    0.18   0.154  0.181 -0.144 -0.279  0.151 -0.269
#  -0.164]. Groundtruth: [0.049]. Predicted: [0.04384018]
# Input: [ 0.          0.1         0.          0.19122875  0.12136893  0.18577376
#  -0.11520668 -0.2902225   0.1521526  -0.2756933  -0.15498801]. Groundtruth: [0.03218316]. Predicted: [0.03178958]
# Input: [ 0.     0.    -0.5    0.182  0.153  0.18  -0.146 -0.278  0.154 -0.268
#  -0.161]. Groundtruth: [0.043]. Predicted: [0.04173586]
# Input: [ 0.          0.7         0.          0.19116183  0.08397859  0.1853838
#  -0.09435631 -0.2883997   0.1655944  -0.2771371  -0.18924958]. Groundtruth: [0.08511057]. Predicted: [0.08747589]
# Input: [ 0.     0.     0.3    0.198  0.129  0.194 -0.123 -0.295  0.122 -0.286
#  -0.121]. Groundtruth: [-0.031]. Predicted: [-0.02917913]
# Input: [ 0.     0.     0.7    0.203  0.121  0.195 -0.123 -0.294  0.121 -0.29
#  -0.11 ]. Groundtruth: [-0.046]. Predicted: [-0.04665452]
# Input: [ 0.2    0.     0.     0.156  0.138  0.22  -0.135 -0.255  0.138 -0.311
#  -0.138]. Groundtruth: [0.001]. Predicted: [0.00257881]
# Input: [ 0.          0.4         0.          0.19146858  0.0927798   0.18382144
#  -0.0869382  -0.290461    0.16942917 -0.27760226 -0.18290083]. Groundtruth: [0.07188932]. Predicted: [0.07914671]
# Input: [ 0.     0.     0.4    0.205  0.118  0.195 -0.126 -0.292  0.124 -0.294
#  -0.106]. Groundtruth: [-0.05]. Predicted: [-0.0495348]
# Input: [ 0.          0.2         0.          0.19163243  0.10345768  0.18478177
#  -0.09649184 -0.29042351  0.16512898 -0.27694619 -0.17332286]. Groundtruth: [0.06866486]. Predicted: [0.06267356]
# Input: [ 0.     0.     0.6    0.205  0.118  0.195 -0.126 -0.293  0.125 -0.294
#  -0.107]. Groundtruth: [-0.051]. Predicted: [-0.04922017]
# Input: [ 0.     0.    -0.7    0.18   0.155  0.182 -0.145 -0.278  0.152 -0.27
#  -0.165]. Groundtruth: [0.042]. Predicted: [0.04699292]
# Input: [ 0.         -0.7         0.          0.19906721  0.18666783  0.1909706
#  -0.1754771  -0.28323162  0.09698959 -0.28311372 -0.09281226]. Groundtruth: [-0.08403589]. Predicted: [-0.08373196]
# Input: [ 0.     0.     0.4    0.203  0.12   0.195 -0.123 -0.293  0.124 -0.291
#  -0.11 ]. Groundtruth: [-0.046]. Predicted: [-0.0436754]
# Input: [ 0.3    0.     0.     0.134  0.139  0.231 -0.136 -0.243  0.138 -0.335
#  -0.138]. Groundtruth: [0.002]. Predicted: [0.00271717]
# Input: [ 0.     0.     0.5    0.202  0.121  0.2   -0.123 -0.295  0.119 -0.291
#  -0.112]. Groundtruth: [-0.041]. Predicted: [-0.04424742]
# Input: [ 0.          0.2         0.          0.19147186  0.1032812   0.18412858
#  -0.09583442 -0.29015586  0.16443774 -0.27765238 -0.17348218]. Groundtruth: [0.06887637]. Predicted: [0.06267897]
# Input: [ 0.     0.    -0.3    0.184  0.149  0.182 -0.143 -0.279  0.15  -0.271
#  -0.155]. Groundtruth: [0.032]. Predicted: [0.03103859]
# Input: [ 0.     0.     0.3    0.199  0.127  0.194 -0.124 -0.294  0.124 -0.286
#  -0.12 ]. Groundtruth: [-0.031]. Predicted: [-0.02975177]
# Input: [ 0.         -0.4         0.          0.19776383  0.18417802  0.1918748
#  -0.17963506 -0.28281307  0.09299023 -0.2809945  -0.09728333]. Groundtruth: [-0.08005778]. Predicted: [-0.07730368]
# Input: [ 0.4    0.     0.     0.093  0.137  0.234 -0.137 -0.242  0.138 -0.376
#  -0.136]. Groundtruth: [0.001]. Predicted: [0.00110586]
# Input: [ 0.    -0.6    0.     0.2    0.184  0.193 -0.179 -0.282  0.092 -0.284
#  -0.097]. Groundtruth: [-0.075]. Predicted: [-0.08040849]
# Input: [ 0.4    0.     0.     0.117  0.137  0.234 -0.135 -0.238  0.131 -0.359
#  -0.136]. Groundtruth: [0.002]. Predicted: [-0.00269272]
# Input: [ 0.    -0.1    0.     0.193  0.161  0.188 -0.147 -0.285  0.128 -0.285
#  -0.111]. Groundtruth: [-0.038]. Predicted: [-0.03958083]
# Input: [ 0.     0.    -0.4    0.182  0.153  0.179 -0.146 -0.278  0.155 -0.268
#  -0.16 ]. Groundtruth: [0.043]. Predicted: [0.04037503]
# Input: [ 0.     0.    -0.2    0.186  0.145  0.184 -0.14  -0.283  0.146 -0.274
#  -0.149]. Groundtruth: [0.021]. Predicted: [0.02072329]
# Input: [ 0.     0.    -0.1    0.189  0.14   0.186 -0.137 -0.284  0.142 -0.278
#  -0.142]. Groundtruth: [0.008]. Predicted: [0.00913416]
# Input: [ 0.         -0.6         0.          0.19742115  0.19483913  0.19038057
#  -0.16900247 -0.28251383  0.10536403 -0.28392491 -0.08138427]. Groundtruth: [-0.0982749]. Predicted: [-0.09299763]
# Input: [ 0.     0.     0.7    0.2    0.126  0.192 -0.128 -0.291  0.127 -0.287
#  -0.117]. Groundtruth: [-0.037]. Predicted: [-0.03502047]
# Input: [ 0.    -0.4    0.     0.201  0.192  0.192 -0.168 -0.279  0.099 -0.287
#  -0.084]. Groundtruth: [-0.09]. Predicted: [-0.09139627]
# Input: [ 0.     0.    -0.1    0.189  0.141  0.186 -0.137 -0.285  0.143 -0.275
#  -0.142]. Groundtruth: [0.009]. Predicted: [0.0098489]
# Input: [ 0.     0.    -0.4    0.181  0.154  0.181 -0.145 -0.279  0.152 -0.269
#  -0.162]. Groundtruth: [0.047]. Predicted: [0.04149969]
# Input: [ 0.3    0.     0.     0.131  0.136  0.229 -0.136 -0.249  0.134 -0.342
#  -0.135]. Groundtruth: [-0.001]. Predicted: [-0.00321418]
# Input: [ 0.     0.     0.3    0.199  0.127  0.194 -0.125 -0.292  0.125 -0.286
#  -0.119]. Groundtruth: [-0.03]. Predicted: [-0.03054275]
# Input: [ 0.     0.2    0.     0.191  0.092  0.185 -0.103 -0.288  0.159 -0.277
#  -0.179]. Groundtruth: [0.077]. Predicted: [0.06721437]
# Input: [ 0.     0.     0.7    0.203  0.121  0.196 -0.123 -0.293  0.123 -0.291
#  -0.112]. Groundtruth: [-0.042]. Predicted: [-0.0435764]
# Input: [ 0.         -0.3         0.          0.19888289  0.19453388  0.19015156
#  -0.16837226 -0.28296354  0.10479645 -0.28480619 -0.08146091]. Groundtruth: [-0.09556343]. Predicted: [-0.09104594]
# Input: [ 0.         -0.2         0.          0.19666505  0.17519793  0.19079798
#  -0.16926153 -0.28395718  0.10447311 -0.28217286 -0.10430514]. Groundtruth: [-0.06525224]. Predicted: [-0.06112203]
# Input: [ 0.         -0.5         0.          0.19879332  0.18961573  0.19039373
#  -0.17346318 -0.28298929  0.09999265 -0.28360134 -0.08986717]. Groundtruth: [-0.08371568]. Predicted: [-0.08441923]
# Input: [ 0.         -0.4         0.          0.19793487  0.19867332  0.18987577
#  -0.1656777  -0.28245211  0.10784371 -0.28516418 -0.07591072]. Groundtruth: [-0.08963236]. Predicted: [-0.09714204]
# Input: [ 0.          0.6         0.          0.19114628  0.08697378  0.18575805
#  -0.09314299 -0.28873309  0.1673072  -0.27620202 -0.18726474]. Groundtruth: [0.08075875]. Predicted: [0.08501839]
# Input: [ 0.          0.6         0.          0.19195798  0.09919258  0.18376702
#  -0.0828764  -0.29054874  0.17449985 -0.27813429 -0.17871365]. Groundtruth: [0.06951322]. Predicted: [0.07763472]
# Input: [ 0.     0.     0.5    0.203  0.123  0.196 -0.123 -0.293  0.122 -0.29
#  -0.114]. Groundtruth: [-0.041]. Predicted: [-0.04021754]
# Input: [ 0.3    0.     0.     0.128  0.137  0.227 -0.135 -0.247  0.138 -0.339
#  -0.137]. Groundtruth: [0.002]. Predicted: [0.00214891]
# Input: [ 0.     0.     0.4    0.203  0.12   0.195 -0.124 -0.293  0.122 -0.292
#  -0.109]. Groundtruth: [-0.047]. Predicted: [-0.04593897]
# Input: [ 0.     0.     0.1    0.193  0.134  0.19  -0.13  -0.289  0.133 -0.281
#  -0.131]. Groundtruth: [-0.011]. Predicted: [-0.00995703]
# Input: [ 0.     0.    -0.1    0.189  0.142  0.184 -0.136 -0.286  0.142 -0.277
#  -0.143]. Groundtruth: [0.014]. Predicted: [0.01056233]
# Input: [ 0.     0.    -0.2    0.187  0.145  0.183 -0.139 -0.283  0.146 -0.273
#  -0.148]. Groundtruth: [0.02]. Predicted: [0.01967027]
# Input: [ 0.         -0.7         0.          0.19987448  0.18826587  0.19110925
#  -0.17432737 -0.28231698  0.09771591 -0.28348035 -0.09152786]. Groundtruth: [-0.08453374]. Predicted: [-0.0850878]
# Input: [ 0.     0.    -0.6    0.181  0.153  0.18  -0.145 -0.279  0.153 -0.268
#  -0.162]. Groundtruth: [0.044]. Predicted: [0.04338606]
# Input: [ 0.          0.6         0.          0.19039628  0.08072567  0.18619889
#  -0.09737722 -0.28901243  0.1646392  -0.27687287 -0.19108781]. Groundtruth: [0.08181505]. Predicted: [0.08839862]
# Input: [ 0.          0.6         0.          0.19155769  0.09278814  0.18445526
#  -0.0883698  -0.28959733  0.17037973 -0.27674156 -0.18364269]. Groundtruth: [0.07857327]. Predicted: [0.08198584]
# Input: [ 0.5    0.     0.     0.115  0.144  0.261 -0.136 -0.208  0.134 -0.356
#  -0.142]. Groundtruth: [0.008]. Predicted: [0.00629285]
# Input: [ 0.7    0.     0.     0.068  0.138  0.246 -0.137 -0.227  0.136 -0.396
#  -0.136]. Groundtruth: [0.002]. Predicted: [0.00199005]
# Input: [ 0.          0.7         0.          0.19172664  0.09276362  0.18424931
#  -0.0880162  -0.29005653  0.17033015 -0.27691042 -0.18361321]. Groundtruth: [0.08662465]. Predicted: [0.08269609]
# Input: [ 0.     0.     0.6    0.204  0.118  0.194 -0.125 -0.292  0.124 -0.295
#  -0.106]. Groundtruth: [-0.052]. Predicted: [-0.05053991]
# Input: [ 0.     0.3    0.     0.191  0.078  0.187 -0.102 -0.287  0.164 -0.278
#  -0.193]. Groundtruth: [0.086]. Predicted: [0.087515]
# Input: [ 0.5    0.     0.     0.102  0.141  0.265 -0.137 -0.211  0.136 -0.357
#  -0.139]. Groundtruth: [0.004]. Predicted: [0.00487634]
# Input: [ 0.     0.    -0.7    0.183  0.152  0.18  -0.146 -0.278  0.155 -0.268
#  -0.16 ]. Groundtruth: [0.042]. Predicted: [0.0419936]
# Input: [ 0.         -0.2         0.          0.19757947  0.1773473   0.19024038
#  -0.16650519 -0.28398669  0.10725046 -0.28308481 -0.10083394]. Groundtruth: [-0.06738691]. Predicted: [-0.06431118]
# Input: [ 0.6    0.     0.     0.079  0.139  0.25  -0.138 -0.226  0.136 -0.38
#  -0.136]. Groundtruth: [0.002]. Predicted: [0.00194998]
# Input: [ 0.1    0.     0.     0.173  0.137  0.203 -0.133 -0.271  0.138 -0.293
#  -0.137]. Groundtruth: [0.]. Predicted: [0.00151127]
# Input: [ 0.     0.     0.5    0.205  0.117  0.194 -0.126 -0.292  0.126 -0.296
#  -0.106]. Groundtruth: [-0.047]. Predicted: [-0.04953339]
# Input: [ 0.2    0.     0.     0.161  0.14   0.224 -0.134 -0.251  0.137 -0.306
#  -0.139]. Groundtruth: [0.003]. Predicted: [0.00329083]
# Input: [ 0.6    0.     0.     0.083  0.139  0.252 -0.137 -0.223  0.137 -0.375
#  -0.137]. Groundtruth: [0.004]. Predicted: [0.00378455]
# Input: [ 0.         -0.2         0.          0.19706392  0.18290743  0.18924475
#  -0.16187276 -0.2843343   0.11280608 -0.2841785  -0.09287663]. Groundtruth: [-0.0752164]. Predicted: [-0.07160527]
# Input: [ 0.     0.1    0.     0.19   0.087  0.185 -0.099 -0.289  0.159 -0.28
#  -0.185]. Groundtruth: [0.06]. Predicted: [0.07405257]
# Input: [ 0.     0.     0.5    0.205  0.117  0.194 -0.126 -0.291  0.125 -0.295
#  -0.105]. Groundtruth: [-0.05]. Predicted: [-0.05092767]
# Input: [ 0.          0.3         0.          0.19156092  0.09286584  0.18421163
#  -0.08806172 -0.28976664  0.17035729 -0.27696648 -0.18371969]. Groundtruth: [0.07267261]. Predicted: [0.07968698]
# Input: [ 0.          0.1         0.          0.19116293  0.1188905   0.18552779
#  -0.11580941 -0.28919297  0.14954115 -0.27540839 -0.15451868]. Groundtruth: [0.02768859]. Predicted: [0.03037191]
# Input: [ 0.     0.     0.5    0.201  0.124  0.196 -0.122 -0.295  0.12  -0.289
#  -0.115]. Groundtruth: [-0.039]. Predicted: [-0.0393695]
# Input: [ 0.     0.     0.2    0.197  0.13   0.192 -0.128 -0.29   0.129 -0.284
#  -0.124]. Groundtruth: [-0.023]. Predicted: [-0.02171639]
# Input: [ 0.     0.    -0.1    0.19   0.14   0.188 -0.137 -0.285  0.14  -0.28
#  -0.142]. Groundtruth: [0.012]. Predicted: [0.00763985]
# Input: [ 0.     0.    -0.7    0.18   0.155  0.181 -0.146 -0.278  0.153 -0.268
#  -0.164]. Groundtruth: [0.049]. Predicted: [0.04642694]
# Input: [ 0.         -0.3         0.          0.19842024  0.19704527  0.19064671
#  -0.16697022 -0.28170896  0.10577477 -0.28523797 -0.07852755]. Groundtruth: [-0.09783401]. Predicted: [-0.09413025]
# Input: [ 0.     0.    -0.1    0.188  0.141  0.184 -0.136 -0.286  0.142 -0.274
#  -0.142]. Groundtruth: [0.011]. Predicted: [0.00998027]
# Input: [ 0.    -0.1    0.     0.193  0.159  0.185 -0.145 -0.287  0.127 -0.283
#  -0.111]. Groundtruth: [-0.035]. Predicted: [-0.03927945]
# Input: [ 0.     0.     0.1    0.194  0.133  0.19  -0.131 -0.288  0.133 -0.282
#  -0.129]. Groundtruth: [-0.012]. Predicted: [-0.0127205]
# Input: [ 0.          0.3         0.          0.1911768   0.09262025  0.18511595
#  -0.08894406 -0.28998768  0.17089167 -0.27636489 -0.18380201]. Groundtruth: [0.07658354]. Predicted: [0.07996625]
# Input: [ 0.     0.    -0.4    0.184  0.151  0.177 -0.147 -0.278  0.158 -0.27
#  -0.157]. Groundtruth: [0.036]. Predicted: [0.03737708]
# Input: [ 0.     0.     0.2    0.199  0.127  0.197 -0.123 -0.294  0.122 -0.287
#  -0.117]. Groundtruth: [-0.029]. Predicted: [-0.03389681]
# Input: [ 0.     0.     0.5    0.2    0.127  0.196 -0.119 -0.298  0.115 -0.288
#  -0.117]. Groundtruth: [-0.036]. Predicted: [-0.03856917]
# Input: [ 0.          0.4         0.          0.19118901  0.0811176   0.18624513
#  -0.09781981 -0.28782761  0.16456529 -0.27682525 -0.19117329]. Groundtruth: [0.08533248]. Predicted: [0.08677769]
# Input: [ 0.2    0.     0.     0.155  0.138  0.219 -0.134 -0.256  0.139 -0.311
#  -0.138]. Groundtruth: [0.002]. Predicted: [0.00325912]
# Input: [ 0.          0.7         0.          0.19066286  0.07792439  0.18537159
#  -0.09726577 -0.28896612  0.1626202  -0.278779   -0.19357194]. Groundtruth: [0.0850987]. Predicted: [0.09131989]
# Input: [ 0.         -0.3         0.          0.19878997  0.19518046  0.18995385
#  -0.16879788 -0.28325671  0.10513741 -0.2840451  -0.08165459]. Groundtruth: [-0.09000967]. Predicted: [-0.09062427]
# Input: [ 0.         -0.3         0.          0.19916031  0.19125448  0.19077897
#  -0.17193668 -0.28321925  0.1015336  -0.28365648 -0.08763972]. Groundtruth: [-0.08721788]. Predicted: [-0.08496902]
# Input: [ 0.          0.4         0.          0.19025192  0.08956566  0.1852057
#  -0.09037126 -0.28937352  0.16783625 -0.27690688 -0.18548974]. Groundtruth: [0.0865645]. Predicted: [0.08171126]
# Input: [ 0.          0.7         0.          0.1902678   0.07564547  0.18514681
#  -0.09813955 -0.28708225  0.16064006 -0.27984062 -0.19470982]. Groundtruth: [0.0941759]. Predicted: [0.09200585]
# Input: [ 0.     0.     0.7    0.202  0.123  0.196 -0.123 -0.294  0.122 -0.289
#  -0.113]. Groundtruth: [-0.043]. Predicted: [-0.04243071]
# Input: [ 0.6    0.     0.     0.099  0.141  0.263 -0.137 -0.214  0.136 -0.36
#  -0.138]. Groundtruth: [0.003]. Predicted: [0.00375575]
# Input: [ 0.     0.     0.7    0.204  0.119  0.195 -0.125 -0.293  0.124 -0.293
#  -0.109]. Groundtruth: [-0.047]. Predicted: [-0.04738349]
# Input: [ 0.          0.7         0.          0.19097613  0.09913617  0.18431835
#  -0.08351859 -0.29201886  0.17564632 -0.27758449 -0.18017021]. Groundtruth: [0.08144269]. Predicted: [0.08068282]
# Input: [ 0.1    0.     0.     0.171  0.137  0.201 -0.133 -0.273  0.138 -0.297
#  -0.136]. Groundtruth: [-0.001]. Predicted: [6.10575524e-05]
# Input: [ 0.4    0.     0.     0.121  0.139  0.252 -0.134 -0.223  0.137 -0.34
#  -0.138]. Groundtruth: [0.003]. Predicted: [0.00382072]
# Input: [ 0.          0.5         0.          0.19151406  0.08984671  0.18524349
#  -0.09102185 -0.28846246  0.16867976 -0.27655613 -0.18562464]. Groundtruth: [0.09420035]. Predicted: [0.08282546]
# Input: [ 0.6    0.     0.     0.075  0.139  0.246 -0.137 -0.228  0.137 -0.397
#  -0.138]. Groundtruth: [0.004]. Predicted: [0.00329566]
# Input: [ 0.          0.7         0.          0.1918664   0.09786631  0.18478586
#  -0.08527893 -0.29105669  0.17521277 -0.27716124 -0.18130076]. Groundtruth: [0.0749456]. Predicted: [0.08169747]
# Input: [ 0.5    0.     0.     0.09   0.14   0.255 -0.138 -0.221  0.136 -0.371
#  -0.138]. Groundtruth: [0.002]. Predicted: [0.00367132]
# Input: [ 0.          0.7         0.          0.19177096  0.09747097  0.18371283
#  -0.0839026  -0.29145947  0.17391306 -0.27698433 -0.1803771 ]. Groundtruth: [0.07976429]. Predicted: [0.08032679]
# Input: [ 0.     0.     0.7    0.202  0.124  0.196 -0.122 -0.295  0.12  -0.289
#  -0.115]. Groundtruth: [-0.043]. Predicted: [-0.04076455]
# Input: [ 0.          0.6         0.          0.19080572  0.09136349  0.18539232
#  -0.09004217 -0.28950942  0.1695499  -0.27729714 -0.18466301]. Groundtruth: [0.08698031]. Predicted: [0.08275325]
# Input: [ 0.     0.     0.2    0.196  0.131  0.191 -0.127 -0.292  0.128 -0.283
#  -0.126]. Groundtruth: [-0.02]. Predicted: [-0.0193337]
# Input: [ 0.3    0.     0.     0.132  0.137  0.227 -0.137 -0.249  0.134 -0.342
#  -0.135]. Groundtruth: [0.]. Predicted: [-0.00335609]
# Input: [ 0.         -0.4         0.          0.19996186  0.18719244  0.19165432
#  -0.17557611 -0.28186381  0.09631135 -0.2834661  -0.09302288]. Groundtruth: [-0.07778065]. Predicted: [-0.08153624]
# Input: [ 0.         -0.7         0.          0.19909447  0.19466516  0.19146155
#  -0.16794655 -0.2814422   0.10342712 -0.28549981 -0.08134663]. Groundtruth: [-0.09661071]. Predicted: [-0.0950007]
# Input: [ 0.7    0.     0.     0.05   0.138  0.252 -0.137 -0.225  0.136 -0.416
#  -0.137]. Groundtruth: [0.003]. Predicted: [0.00298154]
# Input: [ 0.     0.     0.4    0.205  0.117  0.194 -0.126 -0.292  0.126 -0.295
#  -0.106]. Groundtruth: [-0.046]. Predicted: [-0.04877475]
# Input: [ 0.          0.3         0.          0.1906721   0.07517562  0.18576834
#  -0.09965099 -0.28806666  0.16169746 -0.27909112 -0.19549102]. Groundtruth: [0.08745743]. Predicted: [0.08995261]
# Input: [ 0.     0.    -0.2    0.186  0.145  0.184 -0.14  -0.283  0.146 -0.274
#  -0.149]. Groundtruth: [0.019]. Predicted: [0.02072329]
# Input: [ 0.    -0.6    0.     0.198  0.192  0.188 -0.17  -0.285  0.105 -0.285
#  -0.085]. Groundtruth: [-0.091]. Predicted: [-0.08895006]
# Input: [ 0.1    0.     0.     0.172  0.136  0.208 -0.136 -0.269  0.138 -0.3
#  -0.136]. Groundtruth: [-0.002]. Predicted: [-0.00114014]
# Input: [ 0.         -0.6         0.          0.19909139  0.19491588  0.19042464
#  -0.16881165 -0.28272671  0.10452014 -0.28414977 -0.08158375]. Groundtruth: [-0.09424701]. Predicted: [-0.09340104]
# Input: [ 0.          0.7         0.          0.1907517   0.07519872  0.18574986
#  -0.09990737 -0.28732681  0.16174339 -0.27906835 -0.19547577]. Groundtruth: [0.08691029]. Predicted: [0.09315827]
# Input: [ 0.         -0.4         0.          0.19714308  0.19806981  0.19039747
#  -0.16513251 -0.28036183  0.10679187 -0.28491855 -0.0759162 ]. Groundtruth: [-0.09189004]. Predicted: [-0.09717905]
# Input: [ 0.1    0.     0.     0.174  0.138  0.204 -0.135 -0.27   0.138 -0.297
#  -0.138]. Groundtruth: [0.001]. Predicted: [0.00171797]
# Input: [ 0.1    0.     0.     0.174  0.138  0.204 -0.134 -0.27   0.138 -0.294
#  -0.138]. Groundtruth: [0.002]. Predicted: [0.00226525]
# Input: [ 0.     0.    -0.6    0.181  0.154  0.181 -0.145 -0.279  0.152 -0.269
#  -0.162]. Groundtruth: [0.044]. Predicted: [0.04272521]
# Input: [ 0.          0.3         0.          0.19111572  0.09599571  0.18433896
#  -0.08571635 -0.29065555  0.17317767 -0.277758   -0.18204026]. Groundtruth: [0.07662287]. Predicted: [0.07875263]
# Input: [ 0.     0.    -0.4    0.183  0.151  0.178 -0.147 -0.277  0.157 -0.269
#  -0.158]. Groundtruth: [0.045]. Predicted: [0.03851748]
# Input: [ 0.     0.    -0.7    0.183  0.152  0.18  -0.147 -0.277  0.156 -0.268
#  -0.159]. Groundtruth: [0.042]. Predicted: [0.0411257]
# Input: [ 0.     0.     0.5    0.204  0.118  0.197 -0.129 -0.289  0.127 -0.298
#  -0.108]. Groundtruth: [-0.046]. Predicted: [-0.0472088]
# Input: [ 0.     0.    -0.4    0.18   0.154  0.181 -0.145 -0.279  0.152 -0.269
#  -0.163]. Groundtruth: [0.043]. Predicted: [0.04289535]
# Input: [ 0.          0.2         0.          0.1907161   0.09491456  0.18749937
#  -0.10656849 -0.28766832  0.16194448 -0.27666807 -0.17851751]. Groundtruth: [0.06400782]. Predicted: [0.0671794]
# Input: [ 0.     0.    -0.3    0.184  0.149  0.183 -0.143 -0.283  0.148 -0.273
#  -0.156]. Groundtruth: [0.034]. Predicted: [0.03079625]
# Input: [ 0.     0.    -0.6    0.18   0.154  0.18  -0.145 -0.28   0.153 -0.268
#  -0.163]. Groundtruth: [0.048]. Predicted: [0.04466787]
# Input: [ 0.     0.    -0.6    0.18   0.155  0.18  -0.144 -0.28   0.152 -0.269
#  -0.164]. Groundtruth: [0.043]. Predicted: [0.04542991]
# Input: [ 0.          0.7         0.          0.19057281  0.08967344  0.18433049
#  -0.08967762 -0.28966165  0.16750118 -0.27698916 -0.1850557 ]. Groundtruth: [0.08448636]. Predicted: [0.08349808]
# Input: [ 0.1    0.     0.     0.174  0.138  0.204 -0.134 -0.27   0.138 -0.294
#  -0.137]. Groundtruth: [0.003]. Predicted: [0.00103912]
# Input: [ 0.          0.3         0.          0.19080283  0.07849909  0.18562952
#  -0.09892681 -0.28802949  0.1629588  -0.27794158 -0.19348569]. Groundtruth: [0.08974931]. Predicted: [0.08810416]
# Input: [ 0.     0.    -0.3    0.184  0.15   0.183 -0.143 -0.28   0.149 -0.272
#  -0.156]. Groundtruth: [0.033]. Predicted: [0.03152694]
# Input: [ 0.          0.4         0.          0.1901017   0.08109118  0.18674539
#  -0.10085785 -0.28886944  0.16779231 -0.2768867  -0.1929394 ]. Groundtruth: [0.08333324]. Predicted: [0.08992427]
# Input: [ 0.     0.    -0.4    0.181  0.154  0.182 -0.146 -0.278  0.152 -0.269
#  -0.163]. Groundtruth: [0.04]. Predicted: [0.04260599]
# Input: [ 0.2    0.     0.     0.153  0.137  0.217 -0.134 -0.258  0.139 -0.312
#  -0.137]. Groundtruth: [0.001]. Predicted: [0.00228344]
# Input: [ 0.     0.    -0.3    0.184  0.149  0.181 -0.142 -0.281  0.15  -0.27
#  -0.154]. Groundtruth: [0.033]. Predicted: [0.03000124]
# Input: [ 0.6    0.     0.     0.106  0.141  0.271 -0.136 -0.205  0.136 -0.351
#  -0.139]. Groundtruth: [0.007]. Predicted: [0.00521324]
# Input: [ 0.5    0.     0.     0.08   0.139  0.249 -0.138 -0.226  0.136 -0.383
#  -0.137]. Groundtruth: [0.002]. Predicted: [0.0025649]
# Input: [ 0.          0.7         0.          0.1912141   0.07567879  0.18583836
#  -0.10111033 -0.28765196  0.16270718 -0.27962479 -0.19575325]. Groundtruth: [0.08743337]. Predicted: [0.09353337]
# Input: [ 0.     0.     0.7    0.201  0.125  0.196 -0.121 -0.296  0.119 -0.289
#  -0.116]. Groundtruth: [-0.037]. Predicted: [-0.03976403]
# Input: [ 0.     0.    -0.1    0.189  0.141  0.187 -0.139 -0.283  0.143 -0.279
#  -0.143]. Groundtruth: [0.011]. Predicted: [0.01033897]
# Input: [ 0.     0.     0.7    0.201  0.125  0.196 -0.121 -0.295  0.119 -0.289
#  -0.115]. Groundtruth: [-0.041]. Predicted: [-0.04091323]
# Input: [ 0.3    0.     0.     0.137  0.139  0.234 -0.136 -0.241  0.138 -0.329
#  -0.139]. Groundtruth: [0.003]. Predicted: [0.0042025]
# Input: [ 0.     0.     0.1    0.195  0.131  0.189 -0.132 -0.288  0.135 -0.284
#  -0.128]. Groundtruth: [-0.012]. Predicted: [-0.01357473]
# Input: [ 0.         -0.5         0.          0.19726403  0.19671485  0.18994769
#  -0.16753253 -0.28323865  0.1074609  -0.28499165 -0.07852358]. Groundtruth: [-0.10471247]. Predicted: [-0.09494374]
# Input: [ 0.     0.    -0.3    0.185  0.149  0.182 -0.143 -0.279  0.151 -0.271
#  -0.154]. Groundtruth: [0.03]. Predicted: [0.03003389]
# Input: [ 0.1    0.     0.     0.17   0.137  0.201 -0.135 -0.273  0.139 -0.3
#  -0.136]. Groundtruth: [-0.001]. Predicted: [-3.53937077e-05]
# Input: [ 0.         -0.3         0.          0.19911247  0.18798053  0.19076915
#  -0.1743691  -0.28320014  0.09819007 -0.28346384 -0.09141067]. Groundtruth: [-0.08157794]. Predicted: [-0.08175988]
# Input: [ 0.          0.2         0.          0.19049589  0.09443235  0.18524644
#  -0.10196762 -0.28913254  0.16058666 -0.27657503 -0.17883354]. Groundtruth: [0.07584909]. Predicted: [0.06769288]
# Input: [ 0.         -0.4         0.          0.19799872  0.19467351  0.18965037
#  -0.16853075 -0.2838527   0.10595721 -0.28517291 -0.08166099]. Groundtruth: [-0.0992472]. Predicted: [-0.09109445]
# Input: [ 0.2    0.     0.     0.156  0.138  0.22  -0.135 -0.255  0.138 -0.311
#  -0.138]. Groundtruth: [0.001]. Predicted: [0.00257881]
# Input: [ 0.     0.    -0.3    0.184  0.149  0.183 -0.143 -0.28   0.15  -0.271
#  -0.155]. Groundtruth: [0.032]. Predicted: [0.03087456]
# Input: [ 0.         -0.3         0.          0.19785723  0.19318946  0.19038357
#  -0.17054431 -0.28295654  0.10383758 -0.28413999 -0.08443058]. Groundtruth: [-0.08157632]. Predicted: [-0.08771678]
# Input: [ 0.     0.     0.7    0.201  0.124  0.196 -0.121 -0.295  0.119 -0.289
#  -0.114]. Groundtruth: [-0.043]. Predicted: [-0.04210244]
# Input: [ 0.     0.     0.4    0.203  0.122  0.196 -0.124 -0.293  0.121 -0.291
#  -0.111]. Groundtruth: [-0.043]. Predicted: [-0.04389273]
# Input: [ 0.1    0.     0.     0.166  0.136  0.2   -0.136 -0.274  0.139 -0.306
#  -0.136]. Groundtruth: [-0.001]. Predicted: [-0.00029508]
# Input: [ 0.          0.3         0.          0.1912699   0.0782086   0.18520911
#  -0.09819521 -0.28785232  0.16259199 -0.27803016 -0.19311365]. Groundtruth: [0.08511667]. Predicted: [0.08755368]
# Input: [ 0.3    0.     0.     0.137  0.139  0.235 -0.136 -0.24   0.138 -0.324
#  -0.138]. Groundtruth: [0.002]. Predicted: [0.00369557]
# Input: [ 0.     0.     0.4    0.201  0.125  0.196 -0.121 -0.296  0.118 -0.289
#  -0.114]. Groundtruth: [-0.04]. Predicted: [-0.04076896]
# Input: [ 0.         -0.7         0.          0.19815142  0.18607488  0.19114484
#  -0.1771232  -0.28333166  0.09638873 -0.28305745 -0.09434294]. Groundtruth: [-0.08167163]. Predicted: [-0.08210809]
# Input: [ 0.     0.     0.3    0.201  0.123  0.193 -0.127 -0.291  0.128 -0.289
#  -0.115]. Groundtruth: [-0.035]. Predicted: [-0.0349587]
# Input: [ 0.     0.     0.6    0.205  0.117  0.194 -0.126 -0.292  0.126 -0.296
#  -0.106]. Groundtruth: [-0.046]. Predicted: [-0.05014615]
# Input: [ 0.          0.1         0.          0.19057709  0.12108978  0.1873035
#  -0.11573112 -0.28854796  0.15136245 -0.27381009 -0.15431634]. Groundtruth: [0.02930231]. Predicted: [0.03099068]
# Input: [ 0.          0.2         0.          0.19130184  0.09262598  0.18665916
#  -0.10716051 -0.28796792  0.16216011 -0.27783439 -0.18199076]. Groundtruth: [0.06591852]. Predicted: [0.07132261]
# Input: [ 0.     0.    -0.3    0.185  0.148  0.181 -0.143 -0.281  0.151 -0.271
#  -0.153]. Groundtruth: [0.033]. Predicted: [0.02877792]
# Input: [ 0.          0.3         0.          0.19087398  0.0843734   0.18635663
#  -0.09614211 -0.28919917  0.16637282 -0.27698374 -0.18949117]. Groundtruth: [0.09043775]. Predicted: [0.08460397]
# Input: [ 0.     0.     0.2    0.196  0.133  0.192 -0.126 -0.293  0.126 -0.284
#  -0.127]. Groundtruth: [-0.02]. Predicted: [-0.01916356]
# Input: [ 0.         -0.6         0.          0.19815874  0.19860844  0.19040047
#  -0.16593125 -0.28260848  0.10781052 -0.28545499 -0.0761096 ]. Groundtruth: [-0.10096879]. Predicted: [-0.09866818]
# Input: [ 0.         -0.6         0.          0.19761038  0.19846119  0.1898253
#  -0.16590461 -0.28341535  0.10858953 -0.28534663 -0.07611873]. Groundtruth: [-0.10067827]. Predicted: [-0.09824727]
# Input: [ 0.         -0.7         0.          0.19984564  0.19114363  0.19095714
#  -0.17132677 -0.28268725  0.10097945 -0.28405505 -0.08754596]. Groundtruth: [-0.08451098]. Predicted: [-0.08856558]
# Input: [ 0.    -0.4    0.     0.197  0.192  0.189 -0.17  -0.284  0.105 -0.283
#  -0.085]. Groundtruth: [-0.089]. Predicted: [-0.08690545]
# Input: [ 0.          0.6         0.          0.19175023  0.09771937  0.18308637
#  -0.08366534 -0.29023933  0.17335401 -0.27758729 -0.18046199]. Groundtruth: [0.07330914]. Predicted: [0.0794964]
# Input: [ 0.     0.    -0.4    0.182  0.153  0.179 -0.145 -0.279  0.155 -0.268
#  -0.16 ]. Groundtruth: [0.031]. Predicted: [0.04040776]
# Input: [ 0.     0.     0.6    0.201  0.125  0.196 -0.121 -0.295  0.118 -0.29
#  -0.115]. Groundtruth: [-0.041]. Predicted: [-0.0408373]
# Input: [ 0.          0.7         0.          0.19076419  0.08974548  0.18453687
#  -0.09028092 -0.28976676  0.16751127 -0.27653211 -0.18513748]. Groundtruth: [0.07790339]. Predicted: [0.08354164]
# Input: [ 0.          0.1         0.          0.19093834  0.11132812  0.18526171
#  -0.11906744 -0.28812063  0.14647558 -0.2799055  -0.15813489]. Groundtruth: [0.03044774]. Predicted: [0.03301697]
# Input: [ 0.     0.     0.2    0.197  0.13   0.192 -0.128 -0.29   0.13  -0.284
#  -0.125]. Groundtruth: [-0.022]. Predicted: [-0.02009931]
# Input: [ 0.     0.    -0.5    0.183  0.152  0.18  -0.146 -0.277  0.154 -0.269
#  -0.159]. Groundtruth: [0.038]. Predicted: [0.03908205]
# Input: [ 0.     0.     0.2    0.198  0.127  0.192 -0.13  -0.289  0.132 -0.288
#  -0.121]. Groundtruth: [-0.025]. Predicted: [-0.02500657]
# Input: [ 0.     0.    -0.7    0.181  0.154  0.181 -0.145 -0.279  0.153 -0.268
#  -0.162]. Groundtruth: [0.041]. Predicted: [0.0438748]
# Input: [ 0.     0.1    0.     0.191  0.117  0.186 -0.118 -0.289  0.149 -0.276
#  -0.155]. Groundtruth: [0.034]. Predicted: [0.03049511]
# Input: [ 0.          0.1         0.          0.19161917  0.11991789  0.18656613
#  -0.11666942 -0.28889292  0.15058306 -0.27543843 -0.15464549]. Groundtruth: [0.02982897]. Predicted: [0.03065341]
# Input: [ 0.     0.    -0.1    0.188  0.14   0.185 -0.136 -0.285  0.142 -0.275
#  -0.142]. Groundtruth: [0.008]. Predicted: [0.00986114]
# Input: [ 0.     0.     0.6    0.201  0.125  0.196 -0.121 -0.296  0.119 -0.289
#  -0.116]. Groundtruth: [-0.037]. Predicted: [-0.03915127]
# Input: [ 0.          0.6         0.          0.19146167  0.08715948  0.18523347
#  -0.09270656 -0.28825521  0.16720204 -0.27647197 -0.18709658]. Groundtruth: [0.0788717]. Predicted: [0.0848017]
# Input: [ 0.    -0.1    0.     0.193  0.16   0.189 -0.147 -0.284  0.129 -0.282
#  -0.112]. Groundtruth: [-0.038]. Predicted: [-0.03749938]
# Input: [ 0.4    0.     0.     0.094  0.137  0.233 -0.137 -0.242  0.138 -0.373
#  -0.136]. Groundtruth: [0.002]. Predicted: [0.00146104]
# Input: [ 0.     0.     0.6    0.203  0.122  0.196 -0.123 -0.294  0.123 -0.29
#  -0.112]. Groundtruth: [-0.045]. Predicted: [-0.04293161]
# Input: [ 0.     0.    -0.7    0.18   0.154  0.181 -0.145 -0.279  0.153 -0.268
#  -0.163]. Groundtruth: [0.047]. Predicted: [0.04527046]
# Input: [ 0.     0.    -0.2    0.186  0.145  0.183 -0.139 -0.284  0.146 -0.272
#  -0.148]. Groundtruth: [0.022]. Predicted: [0.01990874]
# Input: [ 0.3    0.     0.     0.147  0.14   0.245 -0.134 -0.231  0.137 -0.316
#  -0.14 ]. Groundtruth: [0.005]. Predicted: [0.00523231]
# Input: [ 0.4    0.     0.     0.102  0.138  0.239 -0.137 -0.238  0.137 -0.363
#  -0.136]. Groundtruth: [0.002]. Predicted: [0.00092077]
# Input: [ 0.7    0.     0.     0.12   0.141  0.284 -0.133 -0.192  0.136 -0.342
#  -0.14 ]. Groundtruth: [0.008]. Predicted: [0.0056667]
# Input: [ 0.    -0.1    0.     0.196  0.179  0.19  -0.167 -0.284  0.109 -0.283
#  -0.1  ]. Groundtruth: [-0.051]. Predicted: [-0.06366816]
# Input: [ 0.          0.4         0.          0.19063175  0.07792141  0.18564004
#  -0.09823987 -0.28770551  0.16276546 -0.27830979 -0.1933455 ]. Groundtruth: [0.09629259]. Predicted: [0.08874938]
# Input: [ 0.7    0.     0.     0.087  0.141  0.25  -0.136 -0.221  0.137 -0.375
#  -0.14 ]. Groundtruth: [0.008]. Predicted: [0.00723984]
# Input: [ 0.     0.    -0.7    0.189  0.141  0.186 -0.137 -0.284  0.142 -0.277
#  -0.142]. Groundtruth: [0.02]. Predicted: [0.01291969]
# Input: [ 0.         -0.2         0.          0.19540732  0.18195982  0.18815595
#  -0.16145054 -0.28539041  0.11381596 -0.28392839 -0.09230384]. Groundtruth: [-0.07132021]. Predicted: [-0.07150056]
# Input: [ 0.     0.    -0.2    0.186  0.145  0.183 -0.14  -0.282  0.147 -0.274
#  -0.148]. Groundtruth: [0.033]. Predicted: [0.02005215]
# Input: [ 0.     0.     0.4    0.201  0.124  0.196 -0.122 -0.295  0.12  -0.289
#  -0.115]. Groundtruth: [-0.041]. Predicted: [-0.03875674]
# Input: [ 0.     0.     0.3    0.201  0.123  0.193 -0.127 -0.291  0.128 -0.29
#  -0.115]. Groundtruth: [-0.037]. Predicted: [-0.03510457]
# Input: [ 0.     0.    -0.2    0.186  0.145  0.184 -0.139 -0.283  0.145 -0.274
#  -0.149]. Groundtruth: [0.022]. Predicted: [0.02044199]
# Input: [ 0.          0.7         0.          0.19065301  0.07798785  0.18456069
#  -0.09661747 -0.28800637  0.16188593 -0.27896208 -0.19335669]. Groundtruth: [0.083987]. Predicted: [0.09095707]
# Input: [ 0.5    0.     0.     0.086  0.139  0.251 -0.136 -0.221  0.137 -0.384
#  -0.138]. Groundtruth: [0.004]. Predicted: [0.00344868]
# Input: [ 0.          0.5         0.          0.19067271  0.08384915  0.18566576
#  -0.09412575 -0.28858948  0.16518551 -0.27676564 -0.18899496]. Groundtruth: [0.08324498]. Predicted: [0.08553835]
# Input: [ 0.         -0.5         0.          0.19895963  0.19493933  0.19029039
#  -0.16884814 -0.28280139  0.10456489 -0.28442395 -0.08124822]. Groundtruth: [-0.08843893]. Predicted: [-0.09301477]
# Input: [ 0.1    0.     0.     0.172  0.137  0.202 -0.133 -0.272  0.138 -0.294
#  -0.137]. Groundtruth: [0.]. Predicted: [0.0015451]
# Input: [ 0.     0.    -0.2    0.188  0.144  0.185 -0.14  -0.284  0.144 -0.277
#  -0.148]. Groundtruth: [0.02]. Predicted: [0.01781146]
# Input: [ 0.          0.6         0.          0.18987906  0.08073144  0.18669271
#  -0.10130608 -0.28841341  0.16821098 -0.27620023 -0.19275737]. Groundtruth: [0.08578612]. Predicted: [0.09159994]
# Input: [ 0.         -0.3         0.          0.19969551  0.19118261  0.19039336
#  -0.17154673 -0.28317073  0.10123917 -0.28388017 -0.08768483]. Groundtruth: [-0.09313786]. Predicted: [-0.08506945]
# Input: [ 0.     0.    -0.4    0.183  0.151  0.178 -0.147 -0.278  0.157 -0.27
#  -0.157]. Groundtruth: [0.041]. Predicted: [0.03706856]
# Input: [ 0.     0.    -0.3    0.185  0.148  0.182 -0.141 -0.282  0.147 -0.272
#  -0.15 ]. Groundtruth: [0.029]. Predicted: [0.02344513]
# Input: [ 0.     0.     0.5    0.203  0.12   0.195 -0.123 -0.294  0.123 -0.291
#  -0.11 ]. Groundtruth: [-0.044]. Predicted: [-0.04475604]
# Input: [ 0.     0.    -0.7    0.183  0.152  0.179 -0.146 -0.278  0.156 -0.268
#  -0.159]. Groundtruth: [0.041]. Predicted: [0.04124553]
# Input: [ 0.2    0.     0.     0.137  0.136  0.219 -0.137 -0.257  0.139 -0.336
#  -0.137]. Groundtruth: [0.001]. Predicted: [0.00110565]
# Input: [ 0.3    0.     0.     0.125  0.137  0.226 -0.136 -0.249  0.138 -0.343
#  -0.136]. Groundtruth: [0.]. Predicted: [0.00067147]
# Input: [ 0.     0.    -0.1    0.189  0.141  0.185 -0.136 -0.285  0.142 -0.276
#  -0.142]. Groundtruth: [0.009]. Predicted: [0.00950882]
# Input: [ 0.         -0.6         0.          0.19946779  0.19108152  0.19108121
#  -0.17207205 -0.28250945  0.101021   -0.2836771  -0.08733967]. Groundtruth: [-0.08692054]. Predicted: [-0.0879629]
# Input: [ 0.     0.    -0.6    0.186  0.145  0.184 -0.139 -0.283  0.145 -0.273
#  -0.149]. Groundtruth: [0.029]. Predicted: [0.02303891]
# Input: [ 0.          0.6         0.          0.19162059  0.08698484  0.18435425
#  -0.09033248 -0.28907692  0.16529043 -0.27646846 -0.18659352]. Groundtruth: [0.08238285]. Predicted: [0.08369125]
# Input: [ 0.         -0.6         0.          0.19885662  0.18687443  0.19148529
#  -0.17544183 -0.28245437  0.09667329 -0.28347519 -0.09277524]. Groundtruth: [-0.08089359]. Predicted: [-0.08311008]
# Input: [ 0.     0.    -0.7    0.181  0.154  0.181 -0.145 -0.278  0.153 -0.268
#  -0.162]. Groundtruth: [0.039]. Predicted: [0.04395173]
# Input: [ 0.          0.6         0.          0.19116375  0.08097303  0.18573105
#  -0.09652063 -0.28877395  0.16454183 -0.27762359 -0.19135019]. Groundtruth: [0.09417229]. Predicted: [0.08858653]
# Input: [ 0.     0.    -0.3    0.184  0.15   0.182 -0.142 -0.281  0.15  -0.271
#  -0.156]. Groundtruth: [0.031]. Predicted: [0.0321836]
# Input: [ 0.     0.    -0.1    0.189  0.14   0.185 -0.137 -0.285  0.141 -0.277
#  -0.141]. Groundtruth: [0.006]. Predicted: [0.00767312]
# Input: [ 0.     0.    -0.5    0.185  0.149  0.18  -0.143 -0.281  0.152 -0.272
#  -0.152]. Groundtruth: [0.031]. Predicted: [0.02907258]
# Input: [ 0.     0.     0.7    0.2    0.127  0.197 -0.12  -0.297  0.116 -0.289
#  -0.118]. Groundtruth: [-0.036]. Predicted: [-0.03844332]
# Input: [ 0.     0.    -0.1    0.189  0.141  0.186 -0.137 -0.285  0.143 -0.274
#  -0.143]. Groundtruth: [0.011]. Predicted: [0.0112209]
# Input: [ 0.          0.6         0.          0.19099388  0.0928719   0.18420601
#  -0.0875205  -0.28968954  0.169579   -0.27769616 -0.18335997]. Groundtruth: [0.08683614]. Predicted: [0.08138713]
# Input: [ 0.     0.     0.7    0.203  0.121  0.196 -0.123 -0.294  0.123 -0.291
#  -0.112]. Groundtruth: [-0.042]. Predicted: [-0.04365332]
# Input: [ 0.     0.     0.2    0.198  0.129  0.192 -0.129 -0.29   0.129 -0.285
#  -0.123]. Groundtruth: [-0.028]. Predicted: [-0.02333067]
# Input: [ 0.6    0.     0.     0.097  0.139  0.261 -0.135 -0.214  0.137 -0.361
#  -0.138]. Groundtruth: [0.003]. Predicted: [0.00480725]
# Input: [ 0.         -0.2         0.          0.19666767  0.18438986  0.18973875
#  -0.16098306 -0.28363776  0.11384831 -0.28400978 -0.09028254]. Groundtruth: [-0.07070004]. Predicted: [-0.0742333]
# Input: [ 0.          0.5         0.          0.19017795  0.0751024   0.18485045
#  -0.09811531 -0.28939176  0.1605719  -0.2791127  -0.19500498]. Groundtruth: [0.09484836]. Predicted: [0.09073987]
# Input: [ 0.     0.     0.2    0.197  0.129  0.191 -0.128 -0.29   0.13  -0.285
#  -0.124]. Groundtruth: [-0.02]. Predicted: [-0.02134729]
# Input: [ 0.          0.7         0.          0.19175988  0.09647679  0.18461215
#  -0.08666696 -0.29038328  0.17325987 -0.2770887  -0.1819472 ]. Groundtruth: [0.08071083]. Predicted: [0.08172125]
# Input: [ 0.     0.    -0.7    0.182  0.152  0.178 -0.146 -0.278  0.156 -0.268
#  -0.159]. Groundtruth: [0.045]. Predicted: [0.04150216]
# Input: [ 0.         -0.2         0.          0.1962623   0.18476619  0.1897745
#  -0.16158924 -0.28341106  0.1141023  -0.28416309 -0.09039035]. Groundtruth: [-0.07913274]. Predicted: [-0.07402148]
# Input: [ 0.          0.5         0.          0.1917711   0.09434601  0.18467005
#  -0.087825   -0.29050913  0.1722706  -0.27644035 -0.18305889]. Groundtruth: [0.08206307]. Predicted: [0.08113366]
# Input: [ 0.         -0.3         0.          0.19891591  0.19107248  0.19021058
#  -0.17171039 -0.2833302   0.10176425 -0.28406239 -0.08755885]. Groundtruth: [-0.08644553]. Predicted: [-0.08492328]
# Input: [ 0.     0.     0.1    0.197  0.126  0.196 -0.129 -0.293  0.128 -0.29
#  -0.117]. Groundtruth: [-0.026]. Predicted: [-0.03149389]
# Input: [ 0.     0.    -0.4    0.179  0.154  0.183 -0.144 -0.28   0.15  -0.272
#  -0.163]. Groundtruth: [0.043]. Predicted: [0.04170388]
# Input: [ 0.         -0.4         0.          0.19952701  0.18951777  0.19108129
#  -0.17359087 -0.28301638  0.09965186 -0.28330839 -0.09016845]. Groundtruth: [-0.10536785]. Predicted: [-0.08354031]
# Input: [ 0.          0.1         0.          0.19073775  0.11533909  0.18649946
#  -0.11863855 -0.28837451  0.14847593 -0.27609634 -0.15574752]. Groundtruth: [0.03133725]. Predicted: [0.03123308]
# Input: [ 0.     0.     0.3    0.201  0.122  0.193 -0.128 -0.29   0.128 -0.291
#  -0.113]. Groundtruth: [-0.037]. Predicted: [-0.03769851]
# Input: [ 0.     0.     0.1    0.194  0.134  0.19  -0.13  -0.289  0.133 -0.282
#  -0.132]. Groundtruth: [-0.01]. Predicted: [-0.00904631]
# Input: [ 0.6    0.     0.     0.074  0.139  0.247 -0.138 -0.229  0.136 -0.39
#  -0.136]. Groundtruth: [0.002]. Predicted: [0.00136942]
# Input: [ 0.          0.7         0.          0.19135879  0.09462523  0.18372723
#  -0.08618508 -0.28977334  0.17120364 -0.27795094 -0.18266875]. Groundtruth: [0.08546607]. Predicted: [0.08198946]
# Input: [ 0.         -0.4         0.          0.19913819  0.19141647  0.19073053
#  -0.17179555 -0.28260756  0.10147132 -0.283903   -0.08758619]. Groundtruth: [-0.08403227]. Predicted: [-0.08582719]
# Input: [ 0.          0.4         0.          0.19113605  0.08728351  0.18682326
#  -0.0953071  -0.28842488  0.16831821 -0.27710402 -0.1874356 ]. Groundtruth: [0.07864449]. Predicted: [0.08358198]
# Input: [ 0.    -0.1    0.     0.193  0.157  0.189 -0.151 -0.286  0.123 -0.282
#  -0.119]. Groundtruth: [-0.052]. Predicted: [-0.03174398]
# Input: [ 0.2    0.     0.     0.149  0.137  0.214 -0.135 -0.259  0.139 -0.321
#  -0.136]. Groundtruth: [-0.001]. Predicted: [0.00049729]
# Input: [ 0.     0.    -0.2    0.187  0.145  0.183 -0.14  -0.283  0.146 -0.274
#  -0.148]. Groundtruth: [0.017]. Predicted: [0.01941473]
# Input: [ 0.2    0.     0.     0.162  0.14   0.225 -0.134 -0.25   0.137 -0.304
#  -0.139]. Groundtruth: [0.003]. Predicted: [0.00340287]
# Input: [ 0.     0.    -0.4    0.182  0.153  0.179 -0.145 -0.278  0.154 -0.268
#  -0.16 ]. Groundtruth: [0.039]. Predicted: [0.04009373]
# Input: [ 0.    -0.1    0.     0.193  0.159  0.188 -0.148 -0.285  0.127 -0.283
#  -0.113]. Groundtruth: [-0.036]. Predicted: [-0.03726361]
# Input: [ 0.         -0.2         0.          0.19787903  0.17186649  0.19280392
#  -0.17227653 -0.28289366  0.09883082 -0.27896187 -0.10958422]. Groundtruth: [-0.05496865]. Predicted: [-0.05689305]
# Input: [ 0.     0.     0.7    0.204  0.118  0.195 -0.125 -0.293  0.125 -0.295
#  -0.107]. Groundtruth: [-0.049]. Predicted: [-0.04969962]
# Input: [ 0.          0.2         0.          0.19161119  0.09460609  0.18747579
#  -0.10563589 -0.28738558  0.16126648 -0.27492923 -0.17801078]. Groundtruth: [0.06557062]. Predicted: [0.06653238]
# Input: [ 0.    -0.1    0.     0.194  0.159  0.188 -0.148 -0.285  0.126 -0.283
#  -0.115]. Groundtruth: [-0.036]. Predicted: [-0.03537185]
# Input: [ 0.     0.    -0.7    0.181  0.153  0.183 -0.143 -0.281  0.148 -0.273
#  -0.162]. Groundtruth: [0.041]. Predicted: [0.04111884]
# Input: [ 0.     0.     0.6    0.201  0.124  0.196 -0.122 -0.295  0.12  -0.289
#  -0.115]. Groundtruth: [-0.041]. Predicted: [-0.03998226]
# Input: [ 0.     0.    -0.5    0.182  0.153  0.181 -0.146 -0.278  0.154 -0.269
#  -0.161]. Groundtruth: [0.043]. Predicted: [0.04150289]
# Input: [ 0.          0.4         0.          0.19157852  0.08150768  0.18673626
#  -0.09991734 -0.28844309  0.16830251 -0.27630192 -0.19353087]. Groundtruth: [0.09417876]. Predicted: [0.09080525]
# Input: [ 0.     0.    -0.1    0.189  0.141  0.186 -0.137 -0.285  0.142 -0.276
#  -0.142]. Groundtruth: [0.008]. Predicted: [0.00931207]
# Input: [ 0.     0.     0.2    0.196  0.13   0.192 -0.128 -0.291  0.129 -0.283
#  -0.125]. Groundtruth: [-0.021]. Predicted: [-0.02025179]
# Input: [ 0.          0.4         0.          0.19034983  0.07782378  0.18452282
#  -0.09615454 -0.2884073   0.16138333 -0.27891231 -0.1929819 ]. Groundtruth: [0.08529581]. Predicted: [0.08799871]
# Input: [ 0.          0.6         0.          0.19045556  0.07790042  0.18429245
#  -0.09565078 -0.28896177  0.16093586 -0.27908015 -0.19304207]. Groundtruth: [0.0947435]. Predicted: [0.08947847]
# Input: [ 0.     0.     0.7    0.201  0.125  0.196 -0.121 -0.296  0.119 -0.289
#  -0.116]. Groundtruth: [-0.037]. Predicted: [-0.03976403]
# Input: [ 0.     0.    -0.4    0.182  0.153  0.181 -0.146 -0.279  0.154 -0.268
#  -0.161]. Groundtruth: [0.043]. Predicted: [0.04095908]
# Input: [ 0.     0.     0.2    0.196  0.13   0.192 -0.128 -0.29   0.13  -0.284
#  -0.124]. Groundtruth: [-0.022]. Predicted: [-0.0211559]
# Input: [ 0.3    0.     0.     0.129  0.138  0.226 -0.137 -0.25   0.135 -0.348
#  -0.136]. Groundtruth: [0.]. Predicted: [-0.0021324]
# Input: [ 0.         -0.7         0.          0.19750009  0.19850916  0.18972343
#  -0.16574828 -0.28309307  0.10818397 -0.28482491 -0.0758713 ]. Groundtruth: [-0.10012783]. Predicted: [-0.09936212]
# Input: [ 0.          0.6         0.          0.19188087  0.09458393  0.18350911
#  -0.08570661 -0.29035765  0.17084442 -0.2779696  -0.18235512]. Groundtruth: [0.08795235]. Predicted: [0.08060454]
# Input: [ 0.     0.     0.3    0.199  0.127  0.194 -0.124 -0.293  0.124 -0.287
#  -0.118]. Groundtruth: [-0.033]. Predicted: [-0.03227297]
# Input: [ 0.    -0.7    0.     0.197  0.19   0.19  -0.174 -0.284  0.101 -0.283
#  -0.09 ]. Groundtruth: [-0.08]. Predicted: [-0.0851808]
# Input: [ 0.1    0.     0.     0.167  0.135  0.194 -0.128 -0.277  0.134 -0.309
#  -0.134]. Groundtruth: [-0.003]. Predicted: [-0.00410327]
# Input: [ 0.     0.    -0.1    0.189  0.141  0.185 -0.137 -0.284  0.142 -0.277
#  -0.142]. Groundtruth: [0.009]. Predicted: [0.00933022]
# Input: [ 0.     0.     0.1    0.193  0.135  0.189 -0.13  -0.291  0.132 -0.281
#  -0.132]. Groundtruth: [-0.009]. Predicted: [-0.00922553]
# Input: [ 0.     0.    -0.4    0.18   0.155  0.181 -0.144 -0.28   0.152 -0.269
#  -0.164]. Groundtruth: [0.043]. Predicted: [0.04411729]
# Input: [ 0.          0.3         0.          0.19127858  0.09327844  0.18395953
#  -0.08734162 -0.29010931  0.16969997 -0.27778527 -0.18328196]. Groundtruth: [0.07463322]. Predicted: [0.07888104]
# Input: [ 0.          0.4         0.          0.19132675  0.08981165  0.18538885
#  -0.09173279 -0.28909501  0.16877583 -0.27567452 -0.18549064]. Groundtruth: [0.08624017]. Predicted: [0.08192433]
# Input: [ 0.     0.     0.6    0.202  0.123  0.196 -0.123 -0.294  0.122 -0.289
#  -0.113]. Groundtruth: [-0.045]. Predicted: [-0.04181795]
# Input: [ 0.4    0.     0.     0.085  0.139  0.236 -0.138 -0.233  0.137 -0.386
#  -0.137]. Groundtruth: [0.004]. Predicted: [0.00217321]
# Input: [ 0.7    0.     0.     0.072  0.138  0.262 -0.135 -0.216  0.137 -0.391
#  -0.139]. Groundtruth: [0.006]. Predicted: [0.00578257]
# Input: [ 0.     0.    -0.1    0.188  0.14   0.186 -0.137 -0.285  0.142 -0.277
#  -0.142]. Groundtruth: [0.012]. Predicted: [0.00937264]
# Input: [ 0.          0.2         0.          0.19100225  0.09918536  0.18529928
#  -0.0993139  -0.2894111   0.16162483 -0.276317   -0.17516097]. Groundtruth: [0.06690581]. Predicted: [0.06363704]
# Input: [ 0.     0.     0.3    0.198  0.127  0.194 -0.124 -0.294  0.123 -0.287
#  -0.12 ]. Groundtruth: [-0.03]. Predicted: [-0.03011907]
# Input: [ 0.     0.    -0.1    0.189  0.142  0.186 -0.139 -0.284  0.143 -0.277
#  -0.144]. Groundtruth: [0.01]. Predicted: [0.0118301]
# Input: [ 0.     0.    -0.3    0.183  0.15   0.183 -0.142 -0.281  0.149 -0.271
#  -0.157]. Groundtruth: [0.033]. Predicted: [0.03310121]
# Input: [ 0.     0.     0.6    0.204  0.119  0.196 -0.125 -0.292  0.124 -0.294
#  -0.109]. Groundtruth: [-0.045]. Predicted: [-0.04692677]
# Input: [ 0.         -0.5         0.          0.19835153  0.18486278  0.19194806
#  -0.17819507 -0.28245199  0.09403363 -0.28243041 -0.09558973]. Groundtruth: [-0.08043727]. Predicted: [-0.07992415]
# Input: [ 0.     0.    -0.6    0.182  0.153  0.179 -0.145 -0.278  0.154 -0.268
#  -0.16 ]. Groundtruth: [0.039]. Predicted: [0.04131926]
# Input: [ 0.         -0.6         0.          0.1974858   0.19870958  0.19002889
#  -0.16570905 -0.28316438  0.10806496 -0.28527039 -0.07582247]. Groundtruth: [-0.10372883]. Predicted: [-0.09876952]
# Input: [ 0.     0.     0.3    0.198  0.131  0.194 -0.122 -0.297  0.12  -0.285
#  -0.124]. Groundtruth: [-0.026]. Predicted: [-0.02625482]
# Input: [ 0.4    0.     0.     0.122  0.139  0.253 -0.136 -0.223  0.137 -0.34
#  -0.139]. Groundtruth: [0.004]. Predicted: [0.00457089]
# Input: [ 0.    -0.1    0.     0.195  0.158  0.19  -0.15  -0.284  0.124 -0.282
#  -0.118]. Groundtruth: [-0.032]. Predicted: [-0.03277872]
# Input: [ 0.5    0.     0.     0.084  0.139  0.253 -0.137 -0.223  0.136 -0.373
#  -0.136]. Groundtruth: [0.002]. Predicted: [0.00211143]
# Input: [ 0.     0.     0.1    0.194  0.134  0.19  -0.131 -0.289  0.133 -0.281
#  -0.13 ]. Groundtruth: [-0.011]. Predicted: [-0.01146235]
# Input: [ 0.     0.    -0.5    0.182  0.15   0.18  -0.146 -0.278  0.155 -0.274
#  -0.157]. Groundtruth: [0.037]. Predicted: [0.03645782]
# Input: [ 0.     0.     0.6    0.198  0.129  0.194 -0.123 -0.295  0.121 -0.287
#  -0.122]. Groundtruth: [-0.031]. Predicted: [-0.03032812]
# Input: [ 0.          0.3         0.          0.19119576  0.08992629  0.18499653
#  -0.09104849 -0.28947729  0.16848555 -0.27610707 -0.18552817]. Groundtruth: [0.08204353]. Predicted: [0.0810948]
# Input: [ 0.     0.     0.7    0.203  0.121  0.196 -0.124 -0.294  0.123 -0.29
#  -0.112]. Groundtruth: [-0.042]. Predicted: [-0.04361711]
# ...
# Input: [ 0.         -0.2         0.          0.19554959  0.18704695  0.18875039
#  -0.16001078 -0.28413385  0.1168196  -0.28479287 -0.08645724]. Groundtruth: [-0.07603686]. Predicted: [-0.07763018]
# Input: [ 0.    -0.1    0.     0.193  0.161  0.19  -0.148 -0.283  0.128 -0.283
#  -0.111]. Groundtruth: [-0.043]. Predicted: [-0.03941908]
# Input: [ 0.2    0.     0.     0.147  0.137  0.214 -0.136 -0.26   0.139 -0.325
#  -0.137]. Groundtruth: [0.]. Predicted: [0.0012924]
# Input: [ 0.4    0.     0.     0.099  0.138  0.236 -0.137 -0.239  0.138 -0.372
#  -0.137]. Groundtruth: [0.001]. Predicted: [0.00191796]
# Input: [ 0.     0.     0.6    0.201  0.125  0.195 -0.119 -0.297  0.116 -0.288
#  -0.115]. Groundtruth: [-0.04]. Predicted: [-0.0411749]
# Input: [ 0.     0.    -0.2    0.187  0.145  0.183 -0.14  -0.282  0.147 -0.274
#  -0.148]. Groundtruth: [0.019]. Predicted: [0.01988262]
# Input: [ 0.     0.    -0.6    0.182  0.153  0.18  -0.145 -0.279  0.154 -0.267
#  -0.162]. Groundtruth: [0.042]. Predicted: [0.04375336]
# Input: [ 0.     0.     0.4    0.201  0.124  0.196 -0.123 -0.295  0.121 -0.288
#  -0.114]. Groundtruth: [-0.039]. Predicted: [-0.03955569]
# Input: [ 0.     0.    -0.5    0.183  0.151  0.181 -0.145 -0.279  0.152 -0.274
#  -0.158]. Groundtruth: [0.038]. Predicted: [0.03625026]
# Input: [ 0.          0.2         0.          0.19209461  0.10070944  0.18301387
#  -0.09529398 -0.29006946  0.16073966 -0.27764136 -0.17379954]. Groundtruth: [0.0677786]. Predicted: [0.06177628]
# Input: [ 0.3    0.     0.     0.131  0.138  0.23  -0.136 -0.245  0.138 -0.335
#  -0.138]. Groundtruth: [0.002]. Predicted: [0.00319592]
# Input: [ 0.1    0.     0.     0.174  0.138  0.205 -0.134 -0.27   0.138 -0.294
#  -0.138]. Groundtruth: [0.001]. Predicted: [0.00217815]
# Input: [ 0.     0.    -0.4    0.182  0.152  0.178 -0.146 -0.278  0.156 -0.268
#  -0.158]. Groundtruth: [0.037]. Predicted: [0.03843775]
# Input: [ 0.         -0.4         0.          0.19955818  0.18706012  0.19149503
#  -0.1755365  -0.28292015  0.09666257 -0.28338259 -0.09296017]. Groundtruth: [-0.10304814]. Predicted: [-0.08145336]
# Input: [ 0.         -0.3         0.          0.19943716  0.18371829  0.1924578
#  -0.17897694 -0.28252721  0.09247839 -0.28275883 -0.09728618]. Groundtruth: [-0.07450706]. Predicted: [-0.07718424]
# Input: [ 0.         -0.2         0.          0.19472876  0.18132104  0.19231693
#  -0.15785354 -0.27928585  0.10944773 -0.28913236 -0.08779599]. Groundtruth: [-0.07746027]. Predicted: [-0.07885441]
# Input: [ 0.4    0.     0.     0.105  0.138  0.241 -0.137 -0.236  0.137 -0.356
#  -0.136]. Groundtruth: [0.]. Predicted: [0.00141295]
# Input: [ 0.         -0.5         0.          0.19806941  0.19312626  0.19039975
#  -0.1707637  -0.2825045   0.10383448 -0.28374964 -0.08455208]. Groundtruth: [-0.08851866]. Predicted: [-0.08912992]
# Input: [ 0.1    0.     0.     0.172  0.137  0.203 -0.137 -0.271  0.139 -0.302
#  -0.137]. Groundtruth: [0.]. Predicted: [0.00032026]
# Input: [ 0.          0.5         0.          0.19050843  0.07788892  0.18506145
#  -0.09681913 -0.28814304  0.16206315 -0.27890548 -0.19350855]. Groundtruth: [0.0954351]. Predicted: [0.08957923]
# Input: [ 0.6    0.     0.     0.078  0.139  0.249 -0.137 -0.226  0.137 -0.384
#  -0.137]. Groundtruth: [0.004]. Predicted: [0.00334986]
# Input: [ 0.     0.     0.4    0.203  0.122  0.196 -0.124 -0.294  0.123 -0.291
#  -0.112]. Groundtruth: [-0.045]. Predicted: [-0.04196162]
# Input: [ 0.          0.4         0.          0.19181778  0.09625958  0.18478988
#  -0.08665299 -0.2905103   0.17400201 -0.2764321  -0.18184489]. Groundtruth: [0.07156726]. Predicted: [0.07956595]
# Input: [ 0.3    0.     0.     0.135  0.139  0.232 -0.136 -0.243  0.138 -0.33
#  -0.138]. Groundtruth: [0.002]. Predicted: [0.0031899]
# Input: [ 0.     0.    -0.2    0.186  0.145  0.184 -0.139 -0.283  0.145 -0.274
#  -0.149]. Groundtruth: [0.022]. Predicted: [0.02044199]
# Input: [ 0.     0.     0.6    0.202  0.123  0.196 -0.122 -0.294  0.121 -0.289
#  -0.114]. Groundtruth: [-0.043]. Predicted: [-0.04087312]
# Input: [ 0.     0.     0.6    0.202  0.123  0.196 -0.122 -0.295  0.121 -0.289
#  -0.114]. Groundtruth: [-0.041]. Predicted: [-0.04095004]
# Input: [ 0.     0.    -0.7    0.183  0.152  0.179 -0.146 -0.277  0.155 -0.269
#  -0.158]. Groundtruth: [0.044]. Predicted: [0.0395595]
# Input: [ 0.     0.    -0.7    0.181  0.154  0.181 -0.146 -0.278  0.153 -0.268
#  -0.163]. Groundtruth: [0.045]. Predicted: [0.0450682]
# Input: [ 0.         -0.3         0.          0.19722483  0.19859424  0.1895635
#  -0.16576    -0.28292108  0.10840634 -0.2847181  -0.07597112]. Groundtruth: [-0.10083713]. Predicted: [-0.09588081]
# Input: [ 0.2    0.     0.     0.156  0.138  0.219 -0.134 -0.255  0.138 -0.309
#  -0.138]. Groundtruth: [0.001]. Predicted: [0.00306731]
# Input: [ 0.     0.     0.7    0.201  0.126  0.196 -0.12  -0.297  0.118 -0.289
#  -0.117]. Groundtruth: [-0.041]. Predicted: [-0.03893305]
# Input: [ 0.          0.2         0.          0.19024579  0.08718411  0.18556862
#  -0.10660074 -0.28773016  0.15719029 -0.27911043 -0.18318124]. Groundtruth: [0.06841806]. Predicted: [0.07120775]
# Input: [ 0.     0.     0.2    0.197  0.127  0.194 -0.133 -0.286  0.133 -0.29
#  -0.122]. Groundtruth: [-0.024]. Predicted: [-0.0237841]
# Input: [ 0.    -0.1    0.     0.199  0.184  0.192 -0.178 -0.283  0.094 -0.283
#  -0.096]. Groundtruth: [-0.059]. Predicted: [-0.0764337]
# Input: [ 0.     0.4    0.     0.19   0.087  0.188 -0.099 -0.288  0.172 -0.275
#  -0.189]. Groundtruth: [0.09]. Predicted: [0.08697477]
# Input: [ 0.     0.    -0.7    0.18   0.154  0.18  -0.145 -0.279  0.152 -0.268
#  -0.163]. Groundtruth: [0.045]. Predicted: [0.0449666]
# Input: [ 0.    -0.1    0.     0.193  0.157  0.189 -0.151 -0.286  0.123 -0.282
#  -0.12 ]. Groundtruth: [-0.031]. Predicted: [-0.03051786]
# Input: [ 0.     0.     0.2    0.197  0.13   0.192 -0.128 -0.291  0.13  -0.283
#  -0.126]. Groundtruth: [-0.021]. Predicted: [-0.01880424]
# Input: [ 0.3    0.     0.     0.125  0.137  0.226 -0.136 -0.249  0.138 -0.341
#  -0.136]. Groundtruth: [0.]. Predicted: [0.00096321]
# Input: [ 0.3    0.     0.     0.098  0.14   0.248 -0.138 -0.228  0.136 -0.364
#  -0.136]. Groundtruth: [0.003]. Predicted: [0.00077282]
# Input: [ 0.     0.    -0.4    0.184  0.151  0.178 -0.147 -0.277  0.157 -0.27
#  -0.157]. Groundtruth: [0.035]. Predicted: [0.03697595]
# Input: [ 0.     0.     0.7    0.203  0.122  0.196 -0.124 -0.293  0.123 -0.29
#  -0.112]. Groundtruth: [-0.043]. Predicted: [-0.0435771]
# Input: [ 0.1    0.     0.     0.171  0.137  0.201 -0.134 -0.273  0.139 -0.297
#  -0.137]. Groundtruth: [0.]. Predicted: [0.00156848]
# Input: [ 0.     0.    -0.3    0.184  0.149  0.182 -0.142 -0.281  0.15  -0.271
#  -0.155]. Groundtruth: [0.03]. Predicted: [0.03099439]
# Input: [ 0.     0.     0.5    0.201  0.125  0.196 -0.121 -0.297  0.118 -0.289
#  -0.117]. Groundtruth: [-0.039]. Predicted: [-0.03778027]
# Input: [ 0.          0.4         0.          0.1916046   0.09285131  0.18464459
#  -0.08849483 -0.28991342  0.17074141 -0.27642226 -0.18387607]. Groundtruth: [0.08434403]. Predicted: [0.08080167]
# Input: [ 0.          0.6         0.          0.19124731  0.08080682  0.18402956
#  -0.09378731 -0.28800476  0.1622459  -0.27858001 -0.1912539 ]. Groundtruth: [0.08162385]. Predicted: [0.08793042]
# Input: [ 0.          0.3         0.          0.19142221  0.09286326  0.18398698
#  -0.08762132 -0.28982875  0.16997424 -0.27755386 -0.18355779]. Groundtruth: [0.08454052]. Predicted: [0.07933973]
# Input: [ 0.     0.    -0.4    0.182  0.152  0.179 -0.146 -0.278  0.155 -0.269
#  -0.159]. Groundtruth: [0.037]. Predicted: [0.03903995]
# Input: [ 0.         -0.5         0.          0.1970288   0.19871646  0.18989289
#  -0.16628662 -0.28319746  0.10890746 -0.28475806 -0.07594779]. Groundtruth: [-0.09975295]. Predicted: [-0.0973918]
# Input: [ 0.     0.     0.2    0.196  0.131  0.192 -0.127 -0.291  0.128 -0.284
#  -0.126]. Groundtruth: [-0.027]. Predicted: [-0.01948975]
# Input: [ 0.     0.    -0.5    0.182  0.153  0.18  -0.145 -0.279  0.154 -0.268
#  -0.161]. Groundtruth: [0.04]. Predicted: [0.04176859]
# Input: [ 0.5    0.     0.     0.069  0.138  0.244 -0.138 -0.232  0.136 -0.397
#  -0.136]. Groundtruth: [0.001]. Predicted: [0.00117223]
# Input: [ 0.         -0.7         0.          0.19920421  0.18506616  0.19135956
#  -0.17800437 -0.28329247  0.09397772 -0.28293604 -0.09588122]. Groundtruth: [-0.08298336]. Predicted: [-0.08140041]
# Input: [ 0.         -0.3         0.          0.19806325  0.18278123  0.19211239
#  -0.18011838 -0.28292093  0.09205471 -0.28140631 -0.09893408]. Groundtruth: [-0.07731941]. Predicted: [-0.07498991]
# Input: [ 0.    -0.4    0.     0.198  0.197  0.191 -0.168 -0.282  0.106 -0.284
#  -0.079]. Groundtruth: [-0.096]. Predicted: [-0.09417225]
# Input: [ 0.     0.    -0.3    0.186  0.147  0.181 -0.145 -0.281  0.151 -0.273
#  -0.152]. Groundtruth: [0.027]. Predicted: [0.02690811]
# Input: [ 0.          0.4         0.          0.1910219   0.09272756  0.18533503
#  -0.08901258 -0.29072112  0.17121594 -0.27636081 -0.18396111]. Groundtruth: [0.08286554]. Predicted: [0.08102473]
# Input: [ 0.1    0.     0.     0.169  0.136  0.2   -0.134 -0.274  0.139 -0.301
#  -0.136]. Groundtruth: [-0.001]. Predicted: [0.00014501]
# Input: [ 0.     0.     0.2    0.196  0.132  0.192 -0.127 -0.292  0.128 -0.284
#  -0.127]. Groundtruth: [-0.02]. Predicted: [-0.01837746]
# Input: [ 0.3    0.     0.     0.147  0.138  0.237 -0.135 -0.242  0.134 -0.324
#  -0.136]. Groundtruth: [0.001]. Predicted: [-0.0021973]
# Input: [ 0.          0.2         0.          0.19127229  0.09136173  0.18363656
#  -0.08750027 -0.28952894  0.16783082 -0.27793506 -0.18396306]. Groundtruth: [0.07744505]. Predicted: [0.078294]
# Input: [ 0.     0.1    0.     0.191  0.119  0.184 -0.114 -0.291  0.15  -0.276
#  -0.155]. Groundtruth: [0.032]. Predicted: [0.03127121]
# Input: [ 0.     0.     0.1    0.194  0.133  0.19  -0.131 -0.289  0.134 -0.281
#  -0.13 ]. Groundtruth: [-0.012]. Predicted: [-0.01103447]
# Input: [ 0.     0.     0.5    0.205  0.117  0.195 -0.126 -0.291  0.126 -0.295
#  -0.106]. Groundtruth: [-0.047]. Predicted: [-0.04939768]
# Input: [ 0.          0.2         0.          0.19007154  0.09002478  0.18577403
#  -0.10509657 -0.28877062  0.1579368  -0.27782187 -0.18106297]. Groundtruth: [0.0669075]. Predicted: [0.06908199]
# Input: [ 0.     0.    -0.1    0.189  0.141  0.185 -0.136 -0.285  0.142 -0.276
#  -0.142]. Groundtruth: [0.022]. Predicted: [0.00950882]
# Input: [ 0.    -0.2    0.     0.196  0.176  0.192 -0.169 -0.282  0.104 -0.282
#  -0.103]. Groundtruth: [-0.069]. Predicted: [-0.06272436]
# Input: [ 0.     0.     0.7    0.203  0.121  0.195 -0.123 -0.293  0.121 -0.291
#  -0.11 ]. Groundtruth: [-0.045]. Predicted: [-0.04672346]
# Input: [ 0.         -0.5         0.          0.19811952  0.19627762  0.19002943
#  -0.16691627 -0.2832225   0.10698088 -0.28498745 -0.07859902]. Groundtruth: [-0.09191136]. Predicted: [-0.09510548]
# Input: [ 0.         -0.5         0.          0.19791962  0.19880691  0.19043851
#  -0.16570656 -0.28241518  0.10767502 -0.28532854 -0.07593189]. Groundtruth: [-0.09192999]. Predicted: [-0.09805445]
# Input: [ 0.          0.6         0.          0.19030735  0.0750347   0.18573354
#  -0.10047524 -0.28870779  0.1635386  -0.27908814 -0.19638801]. Groundtruth: [0.09815998]. Predicted: [0.09409329]
# Input: [ 0.     0.     0.3    0.199  0.127  0.194 -0.125 -0.292  0.125 -0.286
#  -0.12 ]. Groundtruth: [-0.031]. Predicted: [-0.02931662]
# Input: [ 0.1    0.     0.     0.163  0.137  0.209 -0.136 -0.268  0.137 -0.312
#  -0.135]. Groundtruth: [-0.001]. Predicted: [-0.003029]
# Input: [ 0.1    0.     0.     0.174  0.136  0.205 -0.136 -0.272  0.137 -0.301
#  -0.136]. Groundtruth: [-0.001]. Predicted: [-0.00198552]
# Input: [ 0.          0.3         0.          0.19118834  0.09602839  0.1841149
#  -0.08546679 -0.29127762  0.17323492 -0.27744365 -0.18201558]. Groundtruth: [0.08752839]. Predicted: [0.07877612]
# Input: [ 0.     0.    -0.6    0.182  0.153  0.18  -0.145 -0.279  0.154 -0.268
#  -0.16 ]. Groundtruth: [0.046]. Predicted: [0.04115523]
# Input: [ 0.     0.    -0.5    0.181  0.154  0.18  -0.145 -0.278  0.153 -0.269
#  -0.162]. Groundtruth: [0.039]. Predicted: [0.04266743]
# Input: [ 0.     0.     0.4    0.203  0.121  0.196 -0.124 -0.293  0.122 -0.29
#  -0.11 ]. Groundtruth: [-0.043]. Predicted: [-0.04454511]
# Input: [ 0.4    0.     0.     0.102  0.138  0.238 -0.137 -0.238  0.137 -0.362
#  -0.137]. Groundtruth: [0.003]. Predicted: [0.00237987]
# Input: [ 0.          0.5         0.          0.19082756  0.08089299  0.18507057
#  -0.09524827 -0.28818452  0.16364917 -0.27777737 -0.19135338]. Groundtruth: [0.08560898]. Predicted: [0.08772462]
# Input: [ 0.1    0.     0.     0.163  0.135  0.194 -0.134 -0.278  0.137 -0.308
#  -0.134]. Groundtruth: [-0.002]. Predicted: [-0.00284129]
# Input: [ 0.     0.     0.6    0.2    0.126  0.196 -0.12  -0.297  0.117 -0.288
#  -0.117]. Groundtruth: [-0.041]. Predicted: [-0.03839584]
# Input: [ 0.4    0.     0.     0.093  0.137  0.234 -0.137 -0.241  0.138 -0.373
#  -0.136]. Groundtruth: [0.002]. Predicted: [0.0016204]
# Input: [ 0.          0.3         0.          0.1909674   0.09114642  0.18509535
#  -0.08926752 -0.28953838  0.16929758 -0.27719444 -0.18450432]. Groundtruth: [0.07733084]. Predicted: [0.08017393]
# Input: [ 0.2    0.     0.     0.15   0.138  0.214 -0.136 -0.26   0.138 -0.319
#  -0.137]. Groundtruth: [0.001]. Predicted: [0.00123117]
# Input: [ 0.3    0.     0.     0.12   0.136  0.223 -0.135 -0.251  0.138 -0.347
#  -0.136]. Groundtruth: [0.001]. Predicted: [0.00118965]
# Input: [ 0.3    0.     0.     0.136  0.139  0.233 -0.135 -0.241  0.138 -0.329
#  -0.138]. Groundtruth: [0.003]. Predicted: [0.00334266]
# Input: [ 0.2    0.     0.     0.151  0.138  0.216 -0.135 -0.258  0.139 -0.317
#  -0.137]. Groundtruth: [0.002]. Predicted: [0.00183366]
# Input: [ 0.5    0.     0.     0.072  0.138  0.247 -0.137 -0.229  0.137 -0.389
#  -0.136]. Groundtruth: [0.003]. Predicted: [0.00230073]
# Input: [ 0.     0.    -0.7    0.182  0.154  0.182 -0.146 -0.278  0.153 -0.269
#  -0.162]. Groundtruth: [0.041]. Predicted: [0.04343957]
# Input: [ 0.     0.     0.2    0.196  0.13   0.192 -0.128 -0.291  0.13  -0.283
#  -0.125]. Groundtruth: [-0.022]. Predicted: [-0.01986083]
# Input: [ 0.     0.    -0.6    0.18   0.155  0.181 -0.145 -0.279  0.151 -0.269
#  -0.163]. Groundtruth: [0.044]. Predicted: [0.043693]
# Input: [ 0.    -0.5    0.     0.197  0.199  0.19  -0.166 -0.283  0.109 -0.285
#  -0.076]. Groundtruth: [-0.096]. Predicted: [-0.0972952]
# Input: [ 0.          0.6         0.          0.19095843  0.08972607  0.18419282
#  -0.08950134 -0.28862488  0.16694808 -0.27746731 -0.18515739]. Groundtruth: [0.07811768]. Predicted: [0.08258378]
# Input: [ 0.1    0.     0.     0.167  0.137  0.193 -0.131 -0.277  0.134 -0.306
#  -0.135]. Groundtruth: [-0.002]. Predicted: [-0.00275523]
# Input: [ 0.     0.    -0.3    0.184  0.149  0.182 -0.143 -0.28   0.149 -0.272
#  -0.156]. Groundtruth: [0.031]. Predicted: [0.03165096]
# Input: [ 0.         -0.6         0.          0.19883059  0.18584323  0.19108611
#  -0.17662799 -0.28324234  0.09566505 -0.28341877 -0.09423143]. Groundtruth: [-0.08461352]. Predicted: [-0.08182399]
# Input: [ 0.     0.     0.4    0.205  0.118  0.195 -0.125 -0.293  0.125 -0.294
#  -0.107]. Groundtruth: [-0.045]. Predicted: [-0.04788499]
# Input: [ 0.          0.4         0.          0.19176598  0.09429887  0.18454641
#  -0.08709407 -0.29036242  0.17200099 -0.27647412 -0.18284793]. Groundtruth: [0.07499558]. Predicted: [0.08007274]
# Input: [ 0.         -0.6         0.          0.19973624  0.19261448  0.1905399
#  -0.17040353 -0.2828843   0.10266921 -0.28373578 -0.08531262]. Groundtruth: [-0.08851506]. Predicted: [-0.08971332]
# Input: [ 0.          0.3         0.          0.19120057  0.08678307  0.18557876
#  -0.0929345  -0.28878218  0.16740054 -0.27618718 -0.18710722]. Groundtruth: [0.08617096]. Predicted: [0.08250619]
# Input: [ 0.     0.     0.5    0.204  0.118  0.197 -0.127 -0.293  0.124 -0.296
#  -0.107]. Groundtruth: [-0.049]. Predicted: [-0.04940444]
# Input: [ 0.          0.2         0.          0.19095649  0.0895579   0.18557078
#  -0.10534745 -0.28798532  0.15798706 -0.27793512 -0.18166359]. Groundtruth: [0.07532895]. Predicted: [0.06973937]

# %%
# Save model
joblib.dump(model_rr_relative_swinging_y, "/home/itaouil/workspace/aliengo_ws/src/aliengo_navigation/models/protocol3/relative/model_rr_relative_swinging_y.sav")
# Out:
# ['/home/itaouil/workspace/aliengo_ws/src/aliengo_navigation/models/protocol3/relative/model_rr_relative_swinging_y.sav']
