# %%
#!/usr/bin/env python3.6
# -*- coding: utf-8 -*-

# %%
# Imports
import sys
import math
import numpy as np
from matplotlib import animation
from IPython.display import HTML
from matplotlib import pyplot as plt
plt.rcParams['animation.ffmpeg_path'] = '/usr/bin/ffmpeg'
import mpl_toolkits.mplot3d.axes3d as p3

# %%
np.random.seed(20)
np.set_printoptions(threshold=sys.maxsize)

# %%
# %matplotlib inline

# %% [markdown]
# # Data

# %%
# Read data
motion = np.genfromtxt('../../dataset4_wbc/live_extraction/step_0.06/continuous.csv', delimiter=',', dtype=np.float64)
contacts = np.genfromtxt('../../dataset4_wbc/live_extraction/step_0.06/continuous.csv', delimiter=',', usecols=(57, 58, 59, 60), dtype=bool)
print("Motion data has a length of ", len(motion))
# Out:
# Motion data has a length of  13434

# %% [markdown]
# ## Height-Force plots

# %%
def get_specific_cmd(dataset, fwd, side, rot):
    if abs(fwd): 
        return np.where(dataset[:, 1] > 0)[0] if fwd > 0 else np.where(dataset[:, 1] < 0)[0]
    if abs(side): 
        return np.where(dataset[:, 2] > 0)[0] if side > 0 else np.where(dataset[:, 2] < 0)[0]
    if abs(rot): 
        return np.where(dataset[:, 3] > 0)[0] if rot > 0 else np.where(dataset[:, 3] < 0)[0]

# %%
def get_swinging_motions(dataset, height=1):
    # rf min height (i.e swining motion)
    fl_min_height = np.where(dataset[:, 10] < height)[0]
    fr_min_height = np.where(dataset[:, 13] < height)[0]
    rl_min_height = np.where(dataset[:, 16] < height)[0]
    rr_min_height = np.where(dataset[:, 19] < height)[0]
            
    return fl_min_height,fr_min_height,rl_min_height,rr_min_height

# %% [markdown]
# ### Step size

# %%
def get_step_size(dataset, footsteps, idx_coord=[8,11,14,17], odom_idx=44):
    # Footsteps sizes
    step_size_fr = []
    step_size_fl = []
    step_size_rr = []
    step_size_rl = []
    footstep_period = []
    
    # Compute step sizes
    for idx, footstep in enumerate(footsteps):
        if idx > 0:
            time_diff = dataset[footsteps[idx], 0] - dataset[footsteps[idx-1], 0]
            
            #print("Time diff: ", time_diff)
            
            if time_diff < 0.5:
                footstep_period.append(time_diff)
                
                if contacts[footsteps[idx], 0]:
                    step_size_fl.append((dataset[footsteps[idx], odom_idx] + dataset[footsteps[idx], idx_coord[0]]) - (dataset[footsteps[idx-1], odom_idx] + dataset[footsteps[idx-1], idx_coord[0]]))
                    step_size_rr.append((dataset[footsteps[idx], odom_idx] + dataset[footsteps[idx], idx_coord[3]]) - (dataset[footsteps[idx-1], odom_idx] + dataset[footsteps[idx-1], idx_coord[3]]))
                else:
                    step_size_fr.append((dataset[footsteps[idx], odom_idx] + dataset[footsteps[idx], idx_coord[1]]) - (dataset[footsteps[idx-1], odom_idx] + dataset[footsteps[idx-1], idx_coord[1]]))
                    step_size_rl.append((dataset[footsteps[idx], odom_idx] + dataset[footsteps[idx], idx_coord[2]]) - (dataset[footsteps[idx-1], odom_idx] + dataset[footsteps[idx-1], idx_coord[2]]))
    
    # Convert to numpy array
    step_size_fl_numpy = np.array(step_size_fl)
    step_size_fr_numpy = np.array(step_size_fr)
    step_size_rl_numpy = np.array(step_size_rl)
    step_size_rr_numpy = np.array(step_size_rr)
    footstep_period_numpy = np.array(footstep_period)
    
    print(min(step_size_fl_numpy), max(step_size_fl_numpy))
    print(min(step_size_fr_numpy), max(step_size_fr_numpy))
    print(min(step_size_rl_numpy), max(step_size_rl_numpy))
    print(min(step_size_rr_numpy), max(step_size_rr_numpy), "\n")
    
    # Print average step-size
    print("Avg. step size time: ", np.mean(footstep_period_numpy))
    print("Min. step size time: ", np.min(footstep_period_numpy))
    print("Max. step size time: ", np.max(footstep_period_numpy))
    print("Std. step size time: ", np.std(footstep_period_numpy), "\n")
    
    #print(footstep_period_numpy)
    print("Avg. step size for fl foot: ", np.mean(step_size_fl_numpy))
    print("Avg. step size for fr foot: ", np.mean(step_size_fr_numpy))
    print("Avg. step size for rl foot: ", np.mean(step_size_rl_numpy))
    print("Avg. step size for rr foot: ", np.mean(step_size_rr_numpy), '\n')

    # Print std. dev. step-size
    print("Std. dev. step size for fl foot: ", np.std(step_size_fl_numpy))
    print("Std. dev. step size for fr foot: ", np.std(step_size_fr_numpy))
    print("Std. dev. step size for rl foot: ", np.std(step_size_rl_numpy))
    print("Std. dev. step size for rr foot: ", np.std(step_size_rr_numpy), '\n')
    
    return step_size_fr_numpy, step_size_fl_numpy, step_size_rr_numpy, step_size_rl_numpy

def step_size_statistics(dataset, footsteps, sign, motion, coordinates=[8,11,14,17], odom_idx=44):
    # Step size and velocity along x axis
    for velocity in np.arange(0.1, 1.0, 0.1):
        print(f"Forward: Step size (x) {velocity * sign}")
        footsteps_velocity = footsteps[np.where((np.isclose(dataset[footsteps, motion], velocity * sign, 0.001)))[0]]
        step_size_fr_x_fwd,_,_,_ = get_step_size(dataset, footsteps_velocity, coordinates, odom_idx)
        print("\n")

# %% [markdown]
# #### Forward motion

# %%
footsteps_fwd = get_specific_cmd(motion, 1, 0, 0)

# %%
# Step size and velocity along x axis
step_size_statistics(motion, footsteps_fwd, 1, 1, [8,11,14,17], 44)
# Out:
# Forward: Step size (x) 0.1
# 0.025142485385663105 0.029579438429935934
# 0.023456837601111502 0.029226358686358922
# 0.0326765587747202 0.03766427654605664
# 0.03640569270547278 0.03994465310103479
#
# Avg. step size time:  0.3819939652964857
# Min. step size time:  0.350266695022583
# Max. step size time:  0.4075765609741211
# Std. step size time:  0.009697975175471916
#
# Avg. step size for fl foot:  0.027849765660133564
# Avg. step size for fr foot:  0.027631743150235064
# Avg. step size for rl foot:  0.03671819785325206
# Avg. step size for rr foot:  0.03856825023181352
#
# Std. dev. step size for fl foot:  0.0005831220608443345
# Std. dev. step size for fr foot:  0.0006667362591555468
# Std. dev. step size for rl foot:  0.0005850389583449959
# Std. dev. step size for rr foot:  0.0005129608204346278
#
#
#
# Forward: Step size (x) 0.2
# 0.0572427978119201 0.061043796920823734
# 0.05427269815851332 0.060262066842067696
# 0.059132981964123754 0.06922465153118473
# 0.05860596524967221 0.06859738215997702
#
# Avg. step size time:  0.3805020703056644
# Min. step size time:  0.3430056571960449
# Max. step size time:  0.42137885093688965
# Std. step size time:  0.010531732572544347
#
# Avg. step size for fl foot:  0.05992198200602224
# Avg. step size for fr foot:  0.05804670788488248
# Avg. step size for rl foot:  0.0656392798806385
# Avg. step size for rr foot:  0.06224870296177276
#
# Std. dev. step size for fl foot:  0.0006687756254675226
# Std. dev. step size for fr foot:  0.0007392679295080461
# Std. dev. step size for rl foot:  0.0010461535691669707
# Std. dev. step size for rr foot:  0.0011450376700511181
#
#
#
# Forward: Step size (x) 0.30000000000000004
# 0.08970009276491808 0.09533128194704688
# 0.08634711623478353 0.09124482909058962
# 0.0893122531411521 0.09899124817932758
# 0.09280551830133632 0.10439009503945229
#
# Avg. step size time:  0.3808698531208202
# Min. step size time:  0.34726595878601074
# Max. step size time:  0.4156973361968994
# Std. step size time:  0.010372250067673882
#
# Avg. step size for fl foot:  0.090882300246139
# Avg. step size for fr foot:  0.08919303117390073
# Avg. step size for rl foot:  0.09793012124160405
# Avg. step size for rr foot:  0.09367928786942774
#
# Std. dev. step size for fl foot:  0.00047907650062129154
# Std. dev. step size for fr foot:  0.0006248761162439908
# Std. dev. step size for rl foot:  0.001121873753172216
# Std. dev. step size for rr foot:  0.0008547583745818753
#
#
#
# Forward: Step size (x) 0.4
# 0.11553878833294462 0.11993961859254298
# 0.11720799094956291 0.12186146380918927
# 0.1142096645780768 0.11737220812013405
# 0.11481525744417809 0.11888767434704306
#
# Avg. step size time:  0.3792344310949015
# Min. step size time:  0.3473806381225586
# Max. step size time:  0.4080171585083008
# Std. step size time:  0.009959238335611475
#
# Avg. step size for fl foot:  0.11645434186113177
# Avg. step size for fr foot:  0.12067046969045293
# Avg. step size for rl foot:  0.1154220350117143
# Avg. step size for rr foot:  0.11608722099199145
#
# Std. dev. step size for fl foot:  0.000487112865750919
# Std. dev. step size for fr foot:  0.0007905286443128841
# Std. dev. step size for rl foot:  0.000572483784618261
# Std. dev. step size for rr foot:  0.00047249986279052916
#
#
#
# Forward: Step size (x) 0.5
# 0.12758752882181312 0.14888323587661034
# 0.14360279156275269 0.1557998945376795
# 0.14594125448639161 0.153610546794976
# 0.12323548803232853 0.14877569836737337
#
# Avg. step size time:  0.38139213190379323
# Min. step size time:  0.3514845371246338
# Max. step size time:  0.41103291511535645
# Std. step size time:  0.009501727729920669
#
# Avg. step size for fl foot:  0.1478004114990544
# Avg. step size for fr foot:  0.14861127715870354
# Avg. step size for rl foot:  0.14767929920955822
# Avg. step size for rr foot:  0.14742004064350445
#
# Std. dev. step size for fl foot:  0.0019162087395955738
# Std. dev. step size for fr foot:  0.0013172939922356242
# Std. dev. step size for rl foot:  0.0008689708335211162
# Std. dev. step size for rr foot:  0.0019158949059260182
#
#
#
# Forward: Step size (x) 0.6
# 0.16388869254550364 0.18673912682615423
# 0.11221857062276896 0.18662458318493336
# 0.1321960673674809 0.19084692739897946
# 0.1743085446306356 0.19020525380194542
#
# Avg. step size time:  0.37888333053700085
# Min. step size time:  0.3474287986755371
# Max. step size time:  0.40917110443115234
# Std. step size time:  0.010597783057051412
#
# Avg. step size for fl foot:  0.17910721687688178
# Avg. step size for fr foot:  0.1785753075287221
# Avg. step size for rl foot:  0.18067046123698052
# Avg. step size for rr foot:  0.18208229934128806
#
# Std. dev. step size for fl foot:  0.0022338209712080425
# Std. dev. step size for fr foot:  0.007270650758706087
# Std. dev. step size for rl foot:  0.006319807822839591
# Std. dev. step size for rr foot:  0.0038333120867987736
#
#
#
# Forward: Step size (x) 0.7000000000000001
# 0.14917966370379787 0.2259815972862249
# 0.14522996968139879 0.22131956067082825
# 0.1575711218329232 0.2189427138208444
# 0.16276794077828782 0.22186551465978965
#
# Avg. step size time:  0.38041353979329956
# Min. step size time:  0.321948766708374
# Max. step size time:  0.4258272647857666
# Std. step size time:  0.012282765453480535
#
# Avg. step size for fl foot:  0.20848751406941254
# Avg. step size for fr foot:  0.2084209755996079
# Avg. step size for rl foot:  0.2116953531745806
# Avg. step size for rr foot:  0.21278416263633523
#
# Std. dev. step size for fl foot:  0.00542818812411555
# Std. dev. step size for fr foot:  0.005563742614999772
# Std. dev. step size for rl foot:  0.006010294397400135
# Std. dev. step size for rr foot:  0.006625711651946816
#
#
#
# Forward: Step size (x) 0.8
# 0.21262419865463045 0.25951823376591676
# 0.16356174433203208 0.25234510777281116
# 0.18241692324856373 0.2496800141566844
# 0.21645278644215438 0.2562117233529193
#
# Avg. step size time:  0.37972233834281427
# Min. step size time:  0.3007683753967285
# Max. step size time:  0.4772791862487793
# Std. step size time:  0.014068922145194562
#
# Avg. step size for fl foot:  0.2396700569139661
# Avg. step size for fr foot:  0.23803958830472455
# Avg. step size for rl foot:  0.23958497850355806
# Avg. step size for rr foot:  0.2418264471884638
#
# Std. dev. step size for fl foot:  0.004651536893450318
# Std. dev. step size for fr foot:  0.007603418203339339
# Std. dev. step size for rl foot:  0.006244342894813543
# Std. dev. step size for rr foot:  0.004926946721484916
#
#
#
# Forward: Step size (x) 0.9
# 0.2580457244851502 0.2871336974756602
# 0.2573902579797398 0.2796386429952804
# 0.25903593670778235 0.27870245505139835
# 0.26219208669644445 0.28653640843148054
#
# Avg. step size time:  0.3819931922274809
# Min. step size time:  0.31880927085876465
# Max. step size time:  0.45521998405456543
# Std. step size time:  0.013769013786198952
#
# Avg. step size for fl foot:  0.2706719668956545
# Avg. step size for fr foot:  0.2699519990652535
# Avg. step size for rl foot:  0.2712806167425554
# Avg. step size for rr foot:  0.2729073302130688
#
# Std. dev. step size for fl foot:  0.003285827482888645
# Std. dev. step size for fr foot:  0.0032748066719295002
# Std. dev. step size for rl foot:  0.004994015125153611
# Std. dev. step size for rr foot:  0.004821964284313157

# %%
# Step size and velocity along y axis
step_size_statistics(motion, footsteps_fwd, 1, 1, [9,12,15,18], 45)
# Out:
# Forward: Step size (x) 0.1
# Avg. step size time:  0.3819939652964857
# Min. step size time:  0.350266695022583
# Max. step size time:  0.4075765609741211
# Std. step size time:  0.009697975175471916
#
# Avg. step size for fl foot:  0.00020466852638753458
# Avg. step size for fr foot:  -0.003059850411818475
# Avg. step size for rl foot:  -0.0005936464408581771
# Avg. step size for rr foot:  -0.0025954323818697805
#
# Std. dev. step size for fl foot:  0.0005071319015979941
# Std. dev. step size for fr foot:  0.0005146275529701143
# Std. dev. step size for rl foot:  0.00044987947465485116
# Std. dev. step size for rr foot:  0.0005494006170287585
#
#
#
# Forward: Step size (x) 0.2
# Avg. step size time:  0.3805020703056644
# Min. step size time:  0.3430056571960449
# Max. step size time:  0.42137885093688965
# Std. step size time:  0.010531732572544347
#
# Avg. step size for fl foot:  0.00012195612817078209
# Avg. step size for fr foot:  -0.0016000278915045392
# Avg. step size for rl foot:  0.0029250662339810065
# Avg. step size for rr foot:  -0.0005461163343979488
#
# Std. dev. step size for fl foot:  0.0004242898180089982
# Std. dev. step size for fr foot:  0.00092385507800386
# Std. dev. step size for rl foot:  0.0009698375333611505
# Std. dev. step size for rr foot:  0.0006086358217043064
#
#
#
# Forward: Step size (x) 0.30000000000000004
# Avg. step size time:  0.3808698531208202
# Min. step size time:  0.34726595878601074
# Max. step size time:  0.4156973361968994
# Std. step size time:  0.010372250067673882
#
# Avg. step size for fl foot:  0.00026800441689055963
# Avg. step size for fr foot:  -0.002198698952767069
# Avg. step size for rl foot:  0.0014463479473711648
# Avg. step size for rr foot:  -0.000312851976614889
#
# Std. dev. step size for fl foot:  0.0003900569496870234
# Std. dev. step size for fr foot:  0.00033871572270060385
# Std. dev. step size for rl foot:  0.0005311975140139226
# Std. dev. step size for rr foot:  0.0006404742818849041
#
#
#
# Forward: Step size (x) 0.4
# Avg. step size time:  0.3792344310949015
# Min. step size time:  0.3473806381225586
# Max. step size time:  0.4080171585083008
# Std. step size time:  0.009959238335611475
#
# Avg. step size for fl foot:  -0.0002582929150540102
# Avg. step size for fr foot:  -8.499738433903805e-05
# Avg. step size for rl foot:  -0.00032727077363452255
# Avg. step size for rr foot:  0.00013961243969193456
#
# Std. dev. step size for fl foot:  0.0003920304040320575
# Std. dev. step size for fr foot:  0.000182261899190271
# Std. dev. step size for rl foot:  0.000248394546504401
# Std. dev. step size for rr foot:  0.00048811898082871865
#
#
#
# Forward: Step size (x) 0.5
# Avg. step size time:  0.38139213190379323
# Min. step size time:  0.3514845371246338
# Max. step size time:  0.41103291511535645
# Std. step size time:  0.009501727729920669
#
# Avg. step size for fl foot:  -0.00106135765703656
# Avg. step size for fr foot:  -0.0009408235691741765
# Avg. step size for rl foot:  -0.0014153397327066465
# Avg. step size for rr foot:  -0.000684916766991003
#
# Std. dev. step size for fl foot:  0.0014760825558350827
# Std. dev. step size for fr foot:  0.0008750333523369903
# Std. dev. step size for rl foot:  0.0010332421379268815
# Std. dev. step size for rr foot:  0.0007441293982980915
#
#
#
# Forward: Step size (x) 0.6
# Avg. step size time:  0.37888333053700085
# Min. step size time:  0.3474287986755371
# Max. step size time:  0.40917110443115234
# Std. step size time:  0.010597783057051412
#
# Avg. step size for fl foot:  -0.00011034648666372865
# Avg. step size for fr foot:  -0.0010834214495112203
# Avg. step size for rl foot:  -0.00031908810343940264
# Avg. step size for rr foot:  -0.0011304850684484681
#
# Std. dev. step size for fl foot:  0.0020442790174611102
# Std. dev. step size for fr foot:  0.007161882316459892
# Std. dev. step size for rl foot:  0.00904727343972489
# Std. dev. step size for rr foot:  0.001432780586570335
#
#
#
# Forward: Step size (x) 0.7000000000000001
# Avg. step size time:  0.38041353979329956
# Min. step size time:  0.321948766708374
# Max. step size time:  0.4258272647857666
# Std. step size time:  0.012282765453480535
#
# Avg. step size for fl foot:  8.961771700239329e-06
# Avg. step size for fr foot:  -0.0022072023060502434
# Avg. step size for rl foot:  -0.0007805769491874914
# Avg. step size for rr foot:  -0.0019329540619981442
#
# Std. dev. step size for fl foot:  0.005780741153505027
# Std. dev. step size for fr foot:  0.006294461914577673
# Std. dev. step size for rl foot:  0.007037265718946412
# Std. dev. step size for rr foot:  0.006485592133388397
#
#
#
# Forward: Step size (x) 0.8
# Avg. step size time:  0.37972233834281427
# Min. step size time:  0.3007683753967285
# Max. step size time:  0.4772791862487793
# Std. step size time:  0.014068922145194562
#
# Avg. step size for fl foot:  0.0005334219727680862
# Avg. step size for fr foot:  -0.003385673543258251
# Avg. step size for rl foot:  -0.0020663042971902613
# Avg. step size for rr foot:  -0.0008403065554058687
#
# Std. dev. step size for fl foot:  0.003568726535436047
# Std. dev. step size for fr foot:  0.007520458801612732
# Std. dev. step size for rl foot:  0.008179662399595538
# Std. dev. step size for rr foot:  0.0029281195915725794
#
#
#
# Forward: Step size (x) 0.9
# Avg. step size time:  0.3819931922274809
# Min. step size time:  0.31880927085876465
# Max. step size time:  0.45521998405456543
# Std. step size time:  0.013769013786198952
#
# Avg. step size for fl foot:  0.0008428517790293313
# Avg. step size for fr foot:  -0.003584223800462176
# Avg. step size for rl foot:  -0.0021892345264525677
# Avg. step size for rr foot:  -0.0005060540559439691
#
# Std. dev. step size for fl foot:  0.0026661769521222145
# Std. dev. step size for fr foot:  0.002839306204787657
# Std. dev. step size for rl foot:  0.003149193269748783
# Std. dev. step size for rr foot:  0.0026094283768033494

# %% [markdown]
# ### Side motion (right)

# %%
footsteps_side_right = get_specific_cmd(motion, 0, -1, 0)

# %%
# Step size and velocity along x axis
step_size_statistics(motion, footsteps_side_right, -1, 2, [8,11,14,17], 44)
# Out:
# Forward: Step size (x) -0.1
# Avg. step size time:  0.38022825208013455
# Min. step size time:  0.3492605686187744
# Max. step size time:  0.4047517776489258
# Std. step size time:  0.010503437227266989
#
# Avg. step size for fl foot:  -0.001656951560300996
# Avg. step size for fr foot:  4.638508137547454e-05
# Avg. step size for rl foot:  0.005382011358634331
# Avg. step size for rr foot:  0.005367867706174206
#
# Std. dev. step size for fl foot:  0.0005502978139872871
# Std. dev. step size for fr foot:  0.0006928462142405261
# Std. dev. step size for rl foot:  0.00039246998363870125
# Std. dev. step size for rr foot:  0.00045376420342318693
#
#
#
# Forward: Step size (x) -0.2
# Avg. step size time:  0.37962976704354273
# Min. step size time:  0.34510207176208496
# Max. step size time:  0.4177563190460205
# Std. step size time:  0.009758163197613214
#
# Avg. step size for fl foot:  -0.0014996393129060085
# Avg. step size for fr foot:  0.0023007557410748896
# Avg. step size for rl foot:  0.006782632345845365
# Avg. step size for rr foot:  0.003892614025792925
#
# Std. dev. step size for fl foot:  0.0007326769616081022
# Std. dev. step size for fr foot:  0.0007963727854634872
# Std. dev. step size for rl foot:  0.0011524238021512858
# Std. dev. step size for rr foot:  0.0007847718121764551
#
#
#
# Forward: Step size (x) -0.30000000000000004
# Avg. step size time:  0.3811299630085855
# Min. step size time:  0.33895444869995117
# Max. step size time:  0.4199666976928711
# Std. step size time:  0.011165150997728723
#
# Avg. step size for fl foot:  -0.003792064449005172
# Avg. step size for fr foot:  0.0012265281078834623
# Avg. step size for rl foot:  0.002246064641615751
# Avg. step size for rr foot:  0.0009581208723710576
#
# Std. dev. step size for fl foot:  0.0029467530248263193
# Std. dev. step size for fr foot:  0.005264097505306112
# Std. dev. step size for rl foot:  0.006488052949959142
# Std. dev. step size for rr foot:  0.0028020578076048347
#
#
#
# Forward: Step size (x) -0.4
# Avg. step size time:  0.38133167049099254
# Min. step size time:  0.3112170696258545
# Max. step size time:  0.4528326988220215
# Std. step size time:  0.013642731666084207
#
# Avg. step size for fl foot:  -0.0040299893694587755
# Avg. step size for fr foot:  0.003213756923144435
# Avg. step size for rl foot:  0.008743392744046825
# Avg. step size for rr foot:  0.003191434284446974
#
# Std. dev. step size for fl foot:  0.0016370266093107006
# Std. dev. step size for fr foot:  0.00128042678280492
# Std. dev. step size for rl foot:  0.003964665413670446
# Std. dev. step size for rr foot:  0.0017897321135100961
#
#
#
# Forward: Step size (x) -0.5
# Avg. step size time:  0.38049457464850256
# Min. step size time:  0.3141670227050781
# Max. step size time:  0.44458460807800293
# Std. step size time:  0.012578024882752377
#
# Avg. step size for fl foot:  -0.0034504368020032133
# Avg. step size for fr foot:  0.005712116449493035
# Avg. step size for rl foot:  0.005516122419947241
# Avg. step size for rr foot:  0.0036904529159558527
#
# Std. dev. step size for fl foot:  0.002117588409578988
# Std. dev. step size for fr foot:  0.0018183860305079399
# Std. dev. step size for rl foot:  0.0034850922718976146
# Std. dev. step size for rr foot:  0.001907261296984924
#
#
#
# Forward: Step size (x) -0.6
# Avg. step size time:  nan
# /home/itaouil/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/itaouil/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a7935af020d5> in <module>
#       1 # Step size and velocity along x axis
# ----> 2 step_size_statistics(motion, footsteps_side_right, -1, 2, [8,11,14,17], 44)
#
# <ipython-input-19-e5d44e7be625> in step_size_statistics(dataset, footsteps, sign, motion, coordinates, odom_idx)
#      56         print(f"Forward: Step size (x) {velocity * sign}")
#      57         footsteps_velocity = footsteps[np.where((np.isclose(dataset[footsteps, motion], velocity * sign, 0.001)))[0]]
# ---> 58         step_size_fr_x_fwd,_,_,_ = get_step_size(dataset, footsteps_velocity, coordinates, odom_idx)
#      59         print("\n")
#
# <ipython-input-19-e5d44e7be625> in get_step_size(dataset, footsteps, idx_coord, odom_idx)
#      33     # Print average step-size
#      34     print("Avg. step size time: ", np.mean(footstep_period_numpy))
# ---> 35     print("Min. step size time: ", np.min(footstep_period_numpy))
#      36     print("Max. step size time: ", np.max(footstep_period_numpy))
#      37     print("Std. step size time: ", np.std(footstep_period_numpy), "\n")
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
# Step size and velocity along y axis
step_size_statistics(motion, footsteps_side_right, -1, 2, [9,12,15,18], 45)
# Out:
# Forward: Step size (x) -0.1
# Avg. step size time:  0.38022825208013455
# Min. step size time:  0.3492605686187744
# Max. step size time:  0.4047517776489258
# Std. step size time:  0.010503437227266989
#
# Avg. step size for fl foot:  -0.03158004675750038
# Avg. step size for fr foot:  -0.034536513621115573
# Avg. step size for rl foot:  -0.03272798571355344
# Avg. step size for rr foot:  -0.03354925523889794
#
# Std. dev. step size for fl foot:  0.0006453878533996306
# Std. dev. step size for fr foot:  0.00044548492925072694
# Std. dev. step size for rl foot:  0.00036578150981072
# Std. dev. step size for rr foot:  0.00023636328463951436
#
#
#
# Forward: Step size (x) -0.2
# Avg. step size time:  0.37962976704354273
# Min. step size time:  0.34510207176208496
# Max. step size time:  0.4177563190460205
# Std. step size time:  0.009758163197613214
#
# Avg. step size for fl foot:  -0.06326890921991703
# Avg. step size for fr foot:  -0.06671825516990425
# Avg. step size for rl foot:  -0.06445901668698867
# Avg. step size for rr foot:  -0.06486512199737296
#
# Std. dev. step size for fl foot:  0.00156976866356367
# Std. dev. step size for fr foot:  0.0013045409531872582
# Std. dev. step size for rl foot:  0.0012363310089006207
# Std. dev. step size for rr foot:  0.000556684480182847
#
#
#
# Forward: Step size (x) -0.30000000000000004
# Avg. step size time:  0.3811299630085855
# Min. step size time:  0.33895444869995117
# Max. step size time:  0.4199666976928711
# Std. step size time:  0.011165150997728723
#
# Avg. step size for fl foot:  -0.09217413522703852
# Avg. step size for fr foot:  -0.09493045409242379
# Avg. step size for rl foot:  -0.0926852485625272
# Avg. step size for rr foot:  -0.09579343447159741
#
# Std. dev. step size for fl foot:  0.0040601048706062825
# Std. dev. step size for fr foot:  0.0062168148598617575
# Std. dev. step size for rl foot:  0.006970971393460791
# Std. dev. step size for rr foot:  0.002258604494466142
#
#
#
# Forward: Step size (x) -0.4
# Avg. step size time:  0.38133167049099254
# Min. step size time:  0.3112170696258545
# Max. step size time:  0.4528326988220215
# Std. step size time:  0.013642731666084207
#
# Avg. step size for fl foot:  -0.12714398307981156
# Avg. step size for fr foot:  -0.13108317115821033
# Avg. step size for rl foot:  -0.1256501080876927
# Avg. step size for rr foot:  -0.1296135464192567
#
# Std. dev. step size for fl foot:  0.004247525940856214
# Std. dev. step size for fr foot:  0.0037593440282407222
# Std. dev. step size for rl foot:  0.002210580959823684
# Std. dev. step size for rr foot:  0.00230410133683345
#
#
#
# Forward: Step size (x) -0.5
# Avg. step size time:  0.38049457464850256
# Min. step size time:  0.3141670227050781
# Max. step size time:  0.44458460807800293
# Std. step size time:  0.012578024882752377
#
# Avg. step size for fl foot:  -0.15716141244146956
# Avg. step size for fr foot:  -0.16050027324904023
# Avg. step size for rl foot:  -0.1582377990914207
# Avg. step size for rr foot:  -0.16013902535036503
#
# Std. dev. step size for fl foot:  0.003218558635585493
# Std. dev. step size for fr foot:  0.0028787048336591996
# Std. dev. step size for rl foot:  0.0019052711117744845
# Std. dev. step size for rr foot:  0.0026559992525932463
#
#
#
# Forward: Step size (x) -0.6
# Avg. step size time:  nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-b68aa41f9298> in <module>
#       1 # Step size and velocity along y axis
# ----> 2 step_size_statistics(motion, footsteps_side_right, -1, 2, [9,12,15,18], 45)
#
# <ipython-input-19-e5d44e7be625> in step_size_statistics(dataset, footsteps, sign, motion, coordinates, odom_idx)
#      56         print(f"Forward: Step size (x) {velocity * sign}")
#      57         footsteps_velocity = footsteps[np.where((np.isclose(dataset[footsteps, motion], velocity * sign, 0.001)))[0]]
# ---> 58         step_size_fr_x_fwd,_,_,_ = get_step_size(dataset, footsteps_velocity, coordinates, odom_idx)
#      59         print("\n")
#
# <ipython-input-19-e5d44e7be625> in get_step_size(dataset, footsteps, idx_coord, odom_idx)
#      33     # Print average step-size
#      34     print("Avg. step size time: ", np.mean(footstep_period_numpy))
# ---> 35     print("Min. step size time: ", np.min(footstep_period_numpy))
#      36     print("Max. step size time: ", np.max(footstep_period_numpy))
#      37     print("Std. step size time: ", np.std(footstep_period_numpy), "\n")
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# ### Side motions (left)

# %%
footsteps_side_left = get_specific_cmd(motion, 0, 1, 0)

# %%
# Step size and velocity along x axis
step_size_statistics(motion, footsteps_side_left, 1, 2, [8,11,14,17], 44)
# Out:
# Forward: Step size (x) 0.1
# Avg. step size time:  0.3798841658157742
# Min. step size time:  0.3491032123565674
# Max. step size time:  0.41736793518066406
# Std. step size time:  0.010505733391411774
#
# Avg. step size for fl foot:  -0.0008809370256323718
# Avg. step size for fr foot:  -0.0026840832613661578
# Avg. step size for rl foot:  0.004217310416480258
# Avg. step size for rr foot:  0.0065092251563989185
#
# Std. dev. step size for fl foot:  0.00047633688973152614
# Std. dev. step size for fr foot:  0.0003251170022705095
# Std. dev. step size for rl foot:  0.00032313239655867176
# Std. dev. step size for rr foot:  0.0003494223282604005
#
#
#
# Forward: Step size (x) 0.2
# Avg. step size time:  0.3806182750658183
# Min. step size time:  0.34891843795776367
# Max. step size time:  0.41597867012023926
# Std. step size time:  0.010043221057127742
#
# Avg. step size for fl foot:  0.001234597262299766
# Avg. step size for fr foot:  -0.0026605391773664366
# Avg. step size for rl foot:  0.0028154222900019866
# Avg. step size for rr foot:  0.008295607047590137
#
# Std. dev. step size for fl foot:  0.0006886398147977647
# Std. dev. step size for fr foot:  0.0006113009062224762
# Std. dev. step size for rl foot:  0.0006645612717161604
# Std. dev. step size for rr foot:  0.0006281182516624873
#
#
#
# Forward: Step size (x) 0.30000000000000004
# Avg. step size time:  0.37920049894815205
# Min. step size time:  0.3157346248626709
# Max. step size time:  0.4436793327331543
# Std. step size time:  0.013839240932931793
#
# Avg. step size for fl foot:  0.0012076636990427988
# Avg. step size for fr foot:  -0.004576442991949242
# Avg. step size for rl foot:  0.002996710179140578
# Avg. step size for rr foot:  0.009052849619795078
#
# Std. dev. step size for fl foot:  0.0052306517064305965
# Std. dev. step size for fr foot:  0.0024358199499856558
# Std. dev. step size for rl foot:  0.0020183729761794568
# Std. dev. step size for rr foot:  0.00588980507606455
#
#
#
# Forward: Step size (x) 0.4
# Avg. step size time:  0.3802632189345086
# Min. step size time:  0.3138997554779053
# Max. step size time:  0.4534773826599121
# Std. step size time:  0.014336761736097981
#
# Avg. step size for fl foot:  0.0030402638596686614
# Avg. step size for fr foot:  -0.0045952370890960945
# Avg. step size for rl foot:  0.003250636633434239
# Avg. step size for rr foot:  0.007463803425875369
#
# Std. dev. step size for fl foot:  0.001267664696564297
# Std. dev. step size for fr foot:  0.0024091772635301415
# Std. dev. step size for rl foot:  0.001648008905020094
# Std. dev. step size for rr foot:  0.004419604958655871
#
#
#
# Forward: Step size (x) 0.5
# Avg. step size time:  0.3806172797194866
# Min. step size time:  0.31961774826049805
# Max. step size time:  0.4480605125427246
# Std. step size time:  0.014542886403766104
#
# Avg. step size for fl foot:  0.005618279630880551
# Avg. step size for fr foot:  -0.002979319057677959
# Avg. step size for rl foot:  0.001985548773972065
# Avg. step size for rr foot:  0.004929887123295497
#
# Std. dev. step size for fl foot:  0.001812220953412319
# Std. dev. step size for fr foot:  0.002569772350191304
# Std. dev. step size for rl foot:  0.0024367822929774173
# Std. dev. step size for rr foot:  0.003534435421653729
#
#
#
# Forward: Step size (x) 0.6
# Avg. step size time:  nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-199876da9b66> in <module>
#       1 # Step size and velocity along x axis
# ----> 2 step_size_statistics(motion, footsteps_side_left, 1, 2, [8,11,14,17], 44)
#
# <ipython-input-19-e5d44e7be625> in step_size_statistics(dataset, footsteps, sign, motion, coordinates, odom_idx)
#      56         print(f"Forward: Step size (x) {velocity * sign}")
#      57         footsteps_velocity = footsteps[np.where((np.isclose(dataset[footsteps, motion], velocity * sign, 0.001)))[0]]
# ---> 58         step_size_fr_x_fwd,_,_,_ = get_step_size(dataset, footsteps_velocity, coordinates, odom_idx)
#      59         print("\n")
#
# <ipython-input-19-e5d44e7be625> in get_step_size(dataset, footsteps, idx_coord, odom_idx)
#      33     # Print average step-size
#      34     print("Avg. step size time: ", np.mean(footstep_period_numpy))
# ---> 35     print("Min. step size time: ", np.min(footstep_period_numpy))
#      36     print("Max. step size time: ", np.max(footstep_period_numpy))
#      37     print("Std. step size time: ", np.std(footstep_period_numpy), "\n")
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
# Step size and velocity along y axis
step_size_statistics(motion, footsteps_side_left, 1, 2, [9,12,15,18], 45)
# Out:
# Forward: Step size (x) 0.1
# Avg. step size time:  0.3798841658157742
# Min. step size time:  0.3491032123565674
# Max. step size time:  0.41736793518066406
# Std. step size time:  0.010505733391411774
#
# Avg. step size for fl foot:  0.03080766915718362
# Avg. step size for fr foot:  0.02809865365154879
# Avg. step size for rl foot:  0.02985586885139943
# Avg. step size for rr foot:  0.028348809243955213
#
# Std. dev. step size for fl foot:  0.0002989337112219531
# Std. dev. step size for fr foot:  0.00029239875152225217
# Std. dev. step size for rl foot:  0.00018051636801389063
# Std. dev. step size for rr foot:  0.0002208390973121732
#
#
#
# Forward: Step size (x) 0.2
# Avg. step size time:  0.3806182750658183
# Min. step size time:  0.34891843795776367
# Max. step size time:  0.41597867012023926
# Std. step size time:  0.010043221057127742
#
# Avg. step size for fl foot:  0.06308059800727013
# Avg. step size for fr foot:  0.06015572489116675
# Avg. step size for rl foot:  0.06140949600155277
# Avg. step size for rr foot:  0.05994301680089101
#
# Std. dev. step size for fl foot:  0.0012273153196239767
# Std. dev. step size for fr foot:  0.0006380889397607125
# Std. dev. step size for rl foot:  0.000669236950216608
# Std. dev. step size for rr foot:  0.001093538192891842
#
#
#
# Forward: Step size (x) 0.30000000000000004
# Avg. step size time:  0.37920049894815205
# Min. step size time:  0.3157346248626709
# Max. step size time:  0.4436793327331543
# Std. step size time:  0.013839240932931793
#
# Avg. step size for fl foot:  0.09633040011707684
# Avg. step size for fr foot:  0.09344252040215247
# Avg. step size for rl foot:  0.09542522666212298
# Avg. step size for rr foot:  0.09102095850650511
#
# Std. dev. step size for fl foot:  0.006150742502246377
# Std. dev. step size for fr foot:  0.0029785596708423773
# Std. dev. step size for rl foot:  0.0020943004813011278
# Std. dev. step size for rr foot:  0.007076581215013805
#
#
#
# Forward: Step size (x) 0.4
# Avg. step size time:  0.3802632189345086
# Min. step size time:  0.3138997554779053
# Max. step size time:  0.4534773826599121
# Std. step size time:  0.014336761736097981
#
# Avg. step size for fl foot:  0.12706133284020468
# Avg. step size for fr foot:  0.1238181111063583
# Avg. step size for rl foot:  0.12557172047034085
# Avg. step size for rr foot:  0.12272909841023216
#
# Std. dev. step size for fl foot:  0.0034264896352591803
# Std. dev. step size for fr foot:  0.0028935889367322685
# Std. dev. step size for rl foot:  0.002703496354140532
# Std. dev. step size for rr foot:  0.0018693851286463764
#
#
#
# Forward: Step size (x) 0.5
# Avg. step size time:  0.3806172797194866
# Min. step size time:  0.31961774826049805
# Max. step size time:  0.4480605125427246
# Std. step size time:  0.014542886403766104
#
# Avg. step size for fl foot:  0.1546212781284851
# Avg. step size for fr foot:  0.15131767041553998
# Avg. step size for rl foot:  0.1549892779139364
# Avg. step size for rr foot:  0.15260959169112287
#
# Std. dev. step size for fl foot:  0.0034226349987277723
# Std. dev. step size for fr foot:  0.003939692697775756
# Std. dev. step size for rl foot:  0.003546997288456706
# Std. dev. step size for rr foot:  0.002564014592723795
#
#
#
# Forward: Step size (x) 0.6
# Avg. step size time:  nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-c88797ce8e4b> in <module>
#       1 # Step size and velocity along y axis
# ----> 2 step_size_statistics(motion, footsteps_side_left, 1, 2, [9,12,15,18], 45)
#
# <ipython-input-19-e5d44e7be625> in step_size_statistics(dataset, footsteps, sign, motion, coordinates, odom_idx)
#      56         print(f"Forward: Step size (x) {velocity * sign}")
#      57         footsteps_velocity = footsteps[np.where((np.isclose(dataset[footsteps, motion], velocity * sign, 0.001)))[0]]
# ---> 58         step_size_fr_x_fwd,_,_,_ = get_step_size(dataset, footsteps_velocity, coordinates, odom_idx)
#      59         print("\n")
#
# <ipython-input-19-e5d44e7be625> in get_step_size(dataset, footsteps, idx_coord, odom_idx)
#      33     # Print average step-size
#      34     print("Avg. step size time: ", np.mean(footstep_period_numpy))
# ---> 35     print("Min. step size time: ", np.min(footstep_period_numpy))
#      36     print("Max. step size time: ", np.max(footstep_period_numpy))
#      37     print("Std. step size time: ", np.std(footstep_period_numpy), "\n")
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# ### Rotation (clockwise)

# %%
footsteps_clock = get_specific_cmd(motion, 0, 0, -1)

# %%
# Step size and velocity along x axis
step_size_statistics(motion, footsteps_clock, -1, 3, [8,11,14,17], 44)
# Out:
# Forward: Step size (x) -0.1
# Avg. step size time:  0.38066780635680275
# Min. step size time:  0.3587915897369385
# Max. step size time:  0.4042966365814209
# Std. step size time:  0.009025129534465583
#
# Avg. step size for fl foot:  0.011663878188712442
# Avg. step size for fr foot:  -0.011492016067493666
# Avg. step size for rl foot:  0.004312870789566378
# Avg. step size for rr foot:  0.004549877082244946
#
# Std. dev. step size for fl foot:  0.018037202068025077
# Std. dev. step size for fr foot:  0.020910273830273985
# Std. dev. step size for rl foot:  0.02105439083981717
# Std. dev. step size for rr foot:  0.018147354647607864
#
#
#
# Forward: Step size (x) -0.2
# Avg. step size time:  0.37939110936271425
# Min. step size time:  0.3243892192840576
# Max. step size time:  0.4390690326690674
# Std. step size time:  0.01566642098998075
#
# Avg. step size for fl foot:  0.02116680858943941
# Avg. step size for fr foot:  -0.020053369470907745
# Avg. step size for rl foot:  0.004614082292406885
# Avg. step size for rr foot:  0.0020075715040527857
#
# Std. dev. step size for fl foot:  0.015621844365586963
# Std. dev. step size for fr foot:  0.01890156686849363
# Std. dev. step size for rl foot:  0.019216991983186788
# Std. dev. step size for rr foot:  0.015386205482112163
#
#
#
# Forward: Step size (x) -0.30000000000000004
# Avg. step size time:  0.3809098137749566
# Min. step size time:  0.31308579444885254
# Max. step size time:  0.46176743507385254
# Std. step size time:  0.022010374438530867
#
# Avg. step size for fl foot:  0.028766543308648525
# Avg. step size for fr foot:  -0.024450084469782953
# Avg. step size for rl foot:  0.0066635581756729215
# Avg. step size for rr foot:  -0.003128774443813898
#
# Std. dev. step size for fl foot:  0.015520999810366741
# Std. dev. step size for fr foot:  0.01716628155459593
# Std. dev. step size for rl foot:  0.017573640049078812
# Std. dev. step size for rr foot:  0.014634690827631303
#
#
#
# Forward: Step size (x) -0.4
# Avg. step size time:  0.3800685111977651
# Min. step size time:  0.35066652297973633
# Max. step size time:  0.4083108901977539
# Std. step size time:  0.010324617845611474
#
# Avg. step size for fl foot:  0.022745657165821866
# Avg. step size for fr foot:  -0.018189257686635252
# Avg. step size for rl foot:  0.014373269750370015
# Avg. step size for rr foot:  -0.026412833093515588
#
# Std. dev. step size for fl foot:  0.0043937277255310875
# Std. dev. step size for fr foot:  0.004957060430107849
# Std. dev. step size for rl foot:  0.004613654709336197
# Std. dev. step size for rr foot:  0.005795176296222145
#
#
#
# Forward: Step size (x) -0.5
# Avg. step size time:  0.38396660099740015
# Min. step size time:  0.352447509765625
# Max. step size time:  0.41443419456481934
# Std. step size time:  0.010572580384233135
#
# Avg. step size for fl foot:  0.02767124206858926
# Avg. step size for fr foot:  -0.019407284522033174
# Avg. step size for rl foot:  0.01776886715537426
# Avg. step size for rr foot:  -0.034567861430243
#
# Std. dev. step size for fl foot:  0.0032311545350816543
# Std. dev. step size for fr foot:  0.0034769577773356547
# Std. dev. step size for rl foot:  0.0036752257478373357
# Std. dev. step size for rr foot:  0.0039436205803438
#
#
#
# Forward: Step size (x) -0.6
# Avg. step size time:  nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-01b84db7b5eb> in <module>
#       1 # Step size and velocity along x axis
# ----> 2 step_size_statistics(motion, footsteps_clock, -1, 3, [8,11,14,17], 44)
#
# <ipython-input-19-e5d44e7be625> in step_size_statistics(dataset, footsteps, sign, motion, coordinates, odom_idx)
#      56         print(f"Forward: Step size (x) {velocity * sign}")
#      57         footsteps_velocity = footsteps[np.where((np.isclose(dataset[footsteps, motion], velocity * sign, 0.001)))[0]]
# ---> 58         step_size_fr_x_fwd,_,_,_ = get_step_size(dataset, footsteps_velocity, coordinates, odom_idx)
#      59         print("\n")
#
# <ipython-input-19-e5d44e7be625> in get_step_size(dataset, footsteps, idx_coord, odom_idx)
#      33     # Print average step-size
#      34     print("Avg. step size time: ", np.mean(footstep_period_numpy))
# ---> 35     print("Min. step size time: ", np.min(footstep_period_numpy))
#      36     print("Max. step size time: ", np.max(footstep_period_numpy))
#      37     print("Std. step size time: ", np.std(footstep_period_numpy), "\n")
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
# Step size along y axis 
step_size_statistics(motion, footsteps_clock, -1, 3, [9,12,15,18], 45)
# Out:
# Forward: Step size (x) -0.1
# Avg. step size time:  0.38066780635680275
# Min. step size time:  0.3587915897369385
# Max. step size time:  0.4042966365814209
# Std. step size time:  0.009025129534465583
#
# Avg. step size for fl foot:  -0.034736189522794406
# Avg. step size for fr foot:  0.016697759012962183
# Avg. step size for rl foot:  0.03707345796178283
# Avg. step size for rr foot:  -0.022626011394994826
#
# Std. dev. step size for fl foot:  0.01779974899953062
# Std. dev. step size for fr foot:  0.020183304460469363
# Std. dev. step size for rl foot:  0.020483974582804744
# Std. dev. step size for rr foot:  0.017532885910129702
#
#
#
# Forward: Step size (x) -0.2
# Avg. step size time:  0.37939110936271425
# Min. step size time:  0.3243892192840576
# Max. step size time:  0.4390690326690674
# Std. step size time:  0.01566642098998075
#
# Avg. step size for fl foot:  -0.037163552106943554
# Avg. step size for fr foot:  0.0033302976380519653
# Avg. step size for rl foot:  0.04222453071791082
# Avg. step size for rr foot:  -0.011946320033522804
#
# Std. dev. step size for fl foot:  0.015765658557259147
# Std. dev. step size for fr foot:  0.01845245961882535
# Std. dev. step size for rl foot:  0.01877321923813266
# Std. dev. step size for rr foot:  0.015130247793155962
#
#
#
# Forward: Step size (x) -0.30000000000000004
# Avg. step size time:  0.3809098137749566
# Min. step size time:  0.31308579444885254
# Max. step size time:  0.46176743507385254
# Std. step size time:  0.022010374438530867
#
# Avg. step size for fl foot:  -0.03891245418396927
# Avg. step size for fr foot:  -0.009946946661812894
# Avg. step size for rl foot:  0.04746541039662893
# Avg. step size for rr foot:  -0.0014916549480829722
#
# Std. dev. step size for fl foot:  0.013765317979922323
# Std. dev. step size for fr foot:  0.016782584524180705
# Std. dev. step size for rl foot:  0.018134083777776235
# Std. dev. step size for rr foot:  0.013690602713980508
#
#
#
# Forward: Step size (x) -0.4
# Avg. step size time:  0.3800685111977651
# Min. step size time:  0.35066652297973633
# Max. step size time:  0.4083108901977539
# Std. step size time:  0.010324617845611474
#
# Avg. step size for fl foot:  -0.027794216042253166
# Avg. step size for fr foot:  -0.0316956710217157
# Avg. step size for rl foot:  0.03546042197824154
# Avg. step size for rr foot:  0.022548633045216232
#
# Std. dev. step size for fl foot:  0.0023531336776714804
# Std. dev. step size for fr foot:  0.0036772648104370746
# Std. dev. step size for rl foot:  0.004171467257739505
# Std. dev. step size for rr foot:  0.0026111632844164415
#
#
#
# Forward: Step size (x) -0.5
# Avg. step size time:  0.38396660099740015
# Min. step size time:  0.352447509765625
# Max. step size time:  0.41443419456481934
# Std. step size time:  0.010572580384233135
#
# Avg. step size for fl foot:  -0.031719915749411416
# Avg. step size for fr foot:  -0.040281703738258234
# Avg. step size for rl foot:  0.04407491280053984
# Avg. step size for rr foot:  0.02754787053698016
#
# Std. dev. step size for fl foot:  0.0020822961723762335
# Std. dev. step size for fr foot:  0.004190581749460834
# Std. dev. step size for rl foot:  0.004784352807598372
# Std. dev. step size for rr foot:  0.0023081331609652567
#
#
#
# Forward: Step size (x) -0.6
# Avg. step size time:  nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-4be44e28b2e1> in <module>
#       1 # Step size along y axis
# ----> 2 step_size_statistics(motion, footsteps_clock, -1, 3, [9,12,15,18], 45)
#
# <ipython-input-19-e5d44e7be625> in step_size_statistics(dataset, footsteps, sign, motion, coordinates, odom_idx)
#      56         print(f"Forward: Step size (x) {velocity * sign}")
#      57         footsteps_velocity = footsteps[np.where((np.isclose(dataset[footsteps, motion], velocity * sign, 0.001)))[0]]
# ---> 58         step_size_fr_x_fwd,_,_,_ = get_step_size(dataset, footsteps_velocity, coordinates, odom_idx)
#      59         print("\n")
#
# <ipython-input-19-e5d44e7be625> in get_step_size(dataset, footsteps, idx_coord, odom_idx)
#      33     # Print average step-size
#      34     print("Avg. step size time: ", np.mean(footstep_period_numpy))
# ---> 35     print("Min. step size time: ", np.min(footstep_period_numpy))
#      36     print("Max. step size time: ", np.max(footstep_period_numpy))
#      37     print("Std. step size time: ", np.std(footstep_period_numpy), "\n")
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# ### Rotation (counter clockwise)

# %%
footsteps_count = get_specific_cmd(motion, 0, 0, 1)

# %%
# Step size and velocity along x axis 
step_size_statistics(motion, footsteps_count, 1, 3, [8,11,14,17], 44)
# Out:
# Forward: Step size (x) 0.1
# Avg. step size time:  0.3813405501466767
# Min. step size time:  0.33509016036987305
# Max. step size time:  0.4242737293243408
# Std. step size time:  0.010916290798776077
#
# Avg. step size for fl foot:  -0.011781950918381197
# Avg. step size for fr foot:  0.011942531088030612
# Avg. step size for rl foot:  0.004248115786111718
# Avg. step size for rr foot:  0.004795793803655842
#
# Std. dev. step size for fl foot:  0.020736925776976996
# Std. dev. step size for fr foot:  0.019638280392251427
# Std. dev. step size for rl foot:  0.020088425322951853
# Std. dev. step size for rr foot:  0.020708382765681033
#
#
#
# Forward: Step size (x) 0.2
# Avg. step size time:  0.38013013454426325
# Min. step size time:  0.33287930488586426
# Max. step size time:  0.4385983943939209
# Std. step size time:  0.010414523349287984
#
# Avg. step size for fl foot:  -0.01971904691233549
# Avg. step size for fr foot:  0.020964839943314745
# Avg. step size for rl foot:  0.0012175585119778086
# Avg. step size for rr foot:  0.006413807792834829
#
# Std. dev. step size for fl foot:  0.01805198858474546
# Std. dev. step size for fr foot:  0.0162564617925701
# Std. dev. step size for rl foot:  0.016779963794699444
# Std. dev. step size for rr foot:  0.01846884220001493
#
#
#
# Forward: Step size (x) 0.30000000000000004
# Avg. step size time:  0.37905139690158013
# Min. step size time:  0.3525691032409668
# Max. step size time:  0.40824103355407715
# Std. step size time:  0.009700375950885704
#
# Avg. step size for fl foot:  -0.017181150970335863
# Avg. step size for fr foot:  0.018518618577255806
# Avg. step size for rl foot:  -0.01715084382940346
# Avg. step size for rr foot:  0.01020056255572065
#
# Std. dev. step size for fl foot:  0.008663365562292481
# Std. dev. step size for fr foot:  0.008453087189201952
# Std. dev. step size for rl foot:  0.010907881402176628
# Std. dev. step size for rr foot:  0.008167713364762694
#
#
#
# Forward: Step size (x) 0.4
# Avg. step size time:  0.3789607599077032
# Min. step size time:  0.3470017910003662
# Max. step size time:  0.4140663146972656
# Std. step size time:  0.009946573859519942
#
# Avg. step size for fl foot:  -0.016956753049389418
# Avg. step size for fr foot:  0.021291992252055327
# Avg. step size for rl foot:  -0.02820860157028504
# Avg. step size for rr foot:  0.015223798357946764
#
# Std. dev. step size for fl foot:  0.0035568398296482494
# Std. dev. step size for fr foot:  0.0024704806364783333
# Std. dev. step size for rl foot:  0.003954117328672208
# Std. dev. step size for rr foot:  0.0033074175558651785
#
#
#
# Forward: Step size (x) 0.5
# Avg. step size time:  0.38211345945866537
# Min. step size time:  0.3540518283843994
# Max. step size time:  0.40700459480285645
# Std. step size time:  0.010152238640978896
#
# Avg. step size for fl foot:  -0.019369369108706406
# Avg. step size for fr foot:  0.028063142251429047
# Avg. step size for rl foot:  -0.03456630713626792
# Avg. step size for rr foot:  0.017777227110774344
#
# Std. dev. step size for fl foot:  0.0028355051838660356
# Std. dev. step size for fr foot:  0.0028196889356197174
# Std. dev. step size for rl foot:  0.003796327115170182
# Std. dev. step size for rr foot:  0.002802230654405105
#
#
#
# Forward: Step size (x) 0.6
# Avg. step size time:  nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-8755827d3914> in <module>
#       1 # Step size and velocity along x axis
# ----> 2 step_size_statistics(motion, footsteps_count, 1, 3, [8,11,14,17], 44)
#
# <ipython-input-19-e5d44e7be625> in step_size_statistics(dataset, footsteps, sign, motion, coordinates, odom_idx)
#      56         print(f"Forward: Step size (x) {velocity * sign}")
#      57         footsteps_velocity = footsteps[np.where((np.isclose(dataset[footsteps, motion], velocity * sign, 0.001)))[0]]
# ---> 58         step_size_fr_x_fwd,_,_,_ = get_step_size(dataset, footsteps_velocity, coordinates, odom_idx)
#      59         print("\n")
#
# <ipython-input-19-e5d44e7be625> in get_step_size(dataset, footsteps, idx_coord, odom_idx)
#      33     # Print average step-size
#      34     print("Avg. step size time: ", np.mean(footstep_period_numpy))
# ---> 35     print("Min. step size time: ", np.min(footstep_period_numpy))
#      36     print("Max. step size time: ", np.max(footstep_period_numpy))
#      37     print("Std. step size time: ", np.std(footstep_period_numpy), "\n")
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
# Step size along y axis 
step_size_statistics(motion, footsteps_count, 1, 3, [9,12,15,18], 45)
# Out:
# Forward: Step size (x) 0.1
# Avg. step size time:  0.3813405501466767
# Min. step size time:  0.33509016036987305
# Max. step size time:  0.4242737293243408
# Std. step size time:  0.010916290798776077
#
# Avg. step size for fl foot:  -0.018497267663974394
# Avg. step size for fr foot:  0.033856408579187494
# Avg. step size for rl foot:  0.021198147158538613
# Avg. step size for rr foot:  -0.040062735586880505
#
# Std. dev. step size for fl foot:  0.018893621285091044
# Std. dev. step size for fr foot:  0.01831665875720727
# Std. dev. step size for rl foot:  0.017946706503109307
# Std. dev. step size for rr foot:  0.018860199211336238
#
#
#
# Forward: Step size (x) 0.2
# Avg. step size time:  0.38013013454426325
# Min. step size time:  0.33287930488586426
# Max. step size time:  0.4385983943939209
# Std. step size time:  0.010414523349287984
#
# Avg. step size for fl foot:  -0.00426504984087913
# Avg. step size for fr foot:  0.035700892181676505
# Avg. step size for rl foot:  0.010115105333422537
# Avg. step size for rr foot:  -0.045378277427250875
#
# Std. dev. step size for fl foot:  0.016918478439380567
# Std. dev. step size for fr foot:  0.01547054416755051
# Std. dev. step size for rl foot:  0.015268260220206402
# Std. dev. step size for rr foot:  0.017015506893962543
#
#
#
# Forward: Step size (x) 0.30000000000000004
# Avg. step size time:  0.37905139690158013
# Min. step size time:  0.3525691032409668
# Max. step size time:  0.40824103355407715
# Std. step size time:  0.009700375950885704
#
# Avg. step size for fl foot:  0.02145487423072086
# Avg. step size for fr foot:  0.022224036413929258
# Avg. step size for rl foot:  -0.017114620384387696
# Avg. step size for rr foot:  -0.029993637690862832
#
# Std. dev. step size for fl foot:  0.011780271556012285
# Std. dev. step size for fr foot:  0.010590071197273492
# Std. dev. step size for rl foot:  0.01271634152923181
# Std. dev. step size for rr foot:  0.01287153649731049
#
#
#
# Forward: Step size (x) 0.4
# Avg. step size time:  0.3789607599077032
# Min. step size time:  0.3470017910003662
# Max. step size time:  0.4140663146972656
# Std. step size time:  0.009946573859519942
#
# Avg. step size for fl foot:  0.03337796456792369
# Avg. step size for fr foot:  0.02334616402246594
# Avg. step size for rl foot:  -0.027325450418135437
# Avg. step size for rr foot:  -0.03344955789650986
#
# Std. dev. step size for fl foot:  0.004928489452111683
# Std. dev. step size for fr foot:  0.003516143698263847
# Std. dev. step size for rl foot:  0.003726460246057386
# Std. dev. step size for rr foot:  0.004591547100763454
#
#
#
# Forward: Step size (x) 0.5
# Avg. step size time:  0.38211345945866537
# Min. step size time:  0.3540518283843994
# Max. step size time:  0.40700459480285645
# Std. step size time:  0.010152238640978896
#
# Avg. step size for fl foot:  0.04077515170288523
# Avg. step size for fr foot:  0.028795111352772785
# Avg. step size for rl foot:  -0.030873520209545112
# Avg. step size for rr foot:  -0.04333598251602147
#
# Std. dev. step size for fl foot:  0.004212542465881577
# Std. dev. step size for fr foot:  0.002250991967727219
# Std. dev. step size for rl foot:  0.002613184296700816
# Std. dev. step size for rr foot:  0.003970524227733717
#
#
#
# Forward: Step size (x) 0.6
# Avg. step size time:  nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-4783dc19ed9a> in <module>
#       1 # Step size along y axis
# ----> 2 step_size_statistics(motion, footsteps_count, 1, 3, [9,12,15,18], 45)
#
# <ipython-input-19-e5d44e7be625> in step_size_statistics(dataset, footsteps, sign, motion, coordinates, odom_idx)
#      56         print(f"Forward: Step size (x) {velocity * sign}")
#      57         footsteps_velocity = footsteps[np.where((np.isclose(dataset[footsteps, motion], velocity * sign, 0.001)))[0]]
# ---> 58         step_size_fr_x_fwd,_,_,_ = get_step_size(dataset, footsteps_velocity, coordinates, odom_idx)
#      59         print("\n")
#
# <ipython-input-19-e5d44e7be625> in get_step_size(dataset, footsteps, idx_coord, odom_idx)
#      33     # Print average step-size
#      34     print("Avg. step size time: ", np.mean(footstep_period_numpy))
# ---> 35     print("Min. step size time: ", np.min(footstep_period_numpy))
#      36     print("Max. step size time: ", np.max(footstep_period_numpy))
#      37     print("Std. step size time: ", np.std(footstep_period_numpy), "\n")
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# ### Footstep visualization

# %%
def euler_from_quaternion(x, y, z, w):
    """
    Convert a quaternion into euler angles (roll, pitch, yaw)
    roll is rotation around x in radians (counterclockwise)
    pitch is rotation around y in radians (counterclockwise)
    yaw is rotation around z in radians (counterclockwise)
    """
    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    roll_x = math.atan2(t0, t1)
     
    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    pitch_y = math.asin(t2)
     
    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    yaw_z = math.atan2(t3, t4)
     
    return roll_x, pitch_y, yaw_z # in radians

# %%
def visualize_static_foosteps(dataset, footsteps):
    old_xs = None
    old_ys = None
    old_zs = None
    
    # Visualize footsteps
    for idx, footstep in enumerate(footsteps):
        fig = plt.figure()
        ax = fig.add_subplot(projection='3d')

        #ax.set_xlim([-0.5, 0.5])
        #ax.set_ylim([-0.3, 0.3])
        ax.set_zlim([-0.5, 0.5])

        dataset[footstep, 8:20] = np.round(dataset[footstep, 8:20], 3)
        
        time_diff = dataset[footsteps[idx], 0] - dataset[footsteps[idx-1], 0]
            
        # 3D positions        
        xs = np.array([dataset[footstep, 8], dataset[footstep, 11], dataset[footstep, 14], dataset[footstep, 17]])
        ys = np.array([dataset[footstep, 9], dataset[footstep, 12], dataset[footstep, 15], dataset[footstep, 18]])
        zz = np.array([dataset[footstep, 10], dataset[footstep, 13], dataset[footstep, 16], dataset[footstep, 19]])

        ax.scatter(xs, ys, zs, marker='o')

        ax.set_xlabel('X Label')
        ax.set_ylabel('Y Label')
        ax.set_zlabel('Z Label')

        plt.show()

        #print(xs, ys, zs, dataset[footstep, 2:5], dataset[footstep, 25:28])
        if idx > 0 and idx < len(footsteps):
            print(f'Diff: {time_diff}. Command: {dataset[footstep, 1:4]}. Coord: {[xs[0], ys[0], zs[0]]}. Step size: {[xs[0]-old_xs[0], ys[0]-old_ys[0], zs[0]-old_zs[0]]}.')
        else:
            print(f'Command: {dataset[footstep, 1:4]}. Coord: {[xs[0], ys[0], zs[0]]}.')
            
        old_xs = xs
        old_ys = ys
        old_zs = zs

# %%
def update_points(num, dataset, footsteps, x, y, z, points):    
    # Starting footstep index
    footstep = footsteps[num]
    
    # Round footsteps position
    dataset[footstep, 8:20] = np.round(dataset[footstep, 8:20], 3)

    # Initial footsteps 3D positions
    new_x = np.array([dataset[footstep, 8], dataset[footstep, 11], dataset[footstep, 14], dataset[footstep, 17]])
    new_y = np.array([dataset[footstep, 9], dataset[footstep, 12], dataset[footstep, 15], dataset[footstep, 18]])
    new_z = np.array([dataset[footstep, 10], dataset[footstep, 13], dataset[footstep, 16], dataset[footstep, 19]])

    # update properties
    points.set_data(new_x, new_y)
    points.set_3d_properties(new_z, 'z')

    # return modified artists
    return points

def visualize_animated_footsteps(dataset, footsteps, style: str):
    # Create figure
    fig = plt.figure()
    ax = p3.Axes3D(fig)

    # Setting the axes properties
    ax.set_xlim3d([-0.4, 0.4])
    ax.set_xlabel('X')

    ax.set_ylim3d([-0.2, 0.2])
    ax.set_ylabel('Y')

    ax.set_zlim3d([-0.5, 0.5])
    ax.set_zlabel('Z')

    # Starting footstep index
    footstep = footsteps[0]

    # Round footsteps position
    dataset[footstep, 8:20] = np.round(dataset[footstep, 8:20], 3)

    # Initial footsteps 3D positions
    x = np.array([dataset[footstep, 8], dataset[footstep, 11], dataset[footstep, 14], dataset[footstep, 17]])
    y = np.array([dataset[footstep, 9], dataset[footstep, 12], dataset[footstep, 15], dataset[footstep, 18]])
    z = np.array([dataset[footstep, 10], dataset[footstep, 13], dataset[footstep, 16], dataset[footstep, 19]])

    txt = fig.suptitle('')
    points, = ax.plot(x, y, z, style)
    
    # blit=True re-draws only the parts that have changed.
    anim = animation.FuncAnimation(fig, update_points, frames=len(footsteps), fargs=(dataset, footsteps, x, y, z, points))
    
    return anim

# %%
def visualize_absolute_foostep_sizes(dataset, footsteps):
    prev_yaw = 0
    
    # Visualize footsteps
    for idx, footstep in enumerate(footsteps):
        dataset[footstep, 8:20] = np.round(dataset[footstep, 8:20], 3)
        
        if idx < (len(footsteps) - 1):
            print("Command: ", dataset[footstep, 1:4])
            time_difference = abs(dataset[footsteps[idx], 0] - dataset[footsteps[idx+1], 0])
            
            if time_difference < 1:
                fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
                axes[0].set_xlabel('X Label')
                axes[0].set_ylabel('Y Label')
                axes[1].set_xlabel('X Label')
                axes[1].set_ylabel('Y Label')
                    
                # Get euler angles from odom to base rotation
                _, _, curh_yaw = euler_from_quaternion(dataset[footstep, 47], dataset[footstep, 48], dataset[footstep, 49], dataset[footstep, 50])
                _, _, next_yaw = euler_from_quaternion(dataset[footsteps[idx+1], 47], dataset[footsteps[idx+1], 48], dataset[footsteps[idx+1], 49], dataset[footsteps[idx+1], 50])

                # Compute rotation matrix
                c_curh, s_curh = np.cos(curh_yaw), np.sin(curh_yaw)
                c_next, s_next = np.cos(next_yaw), np.sin(next_yaw)
                R_curh = np.array(((c_curh, -s_curh), (s_curh, c_curh)))
                R_next = np.array(((c_next, -s_next), (s_next, c_next)))
                
                # Odom base vectors
                curh_base = np.array([[dataset[footstep, 44], dataset[footstep, 45]]])
                next_base = np.array([[dataset[footsteps[idx+1], 44], dataset[footsteps[idx+1], 45]]])
                
                # Local base vectors
                local_curh_base = R_curh.T @ curh_base.T
                local_next_base = R_curh.T @ next_base.T
                local_next_base_next = R_next.T @ next_base.T
                base_displacement = local_next_base - local_curh_base
                
                #print("Footstep timestamp: ", dataset[footstep, 0])
                print(f'\nFL moving: {contacts[idx, 0]}. FR moving: {contacts[idx, 1]}')
                print(f'RL moving: {contacts[idx, 2]}. RR moving: {contacts[idx, 3]}')
                
                #print(f'Curh base (not transformed): {dataset[footstep, 31:33]}. Next base (not transformed): {dataset[footsteps[idx+1], 31:33]}.')
                #print(f'Curh base transformed (x): {local_curh_base.tolist()}.\nNext base transformed (y): {local_next_base.tolist()}.\nNext base transformed2 (y): {local_next_base_next.tolist()}\n')
                print(prev_yaw, curh_yaw)
                print(f'Base displacement: {base_displacement.tolist()}. Rotation displacement: {(curh_yaw - prev_yaw) * 180 / np.pi}.\n')
                
                print("CoM displacement: ")
                print(f'lf (x): {dataset[footsteps[idx], 8]}, {dataset[footsteps[idx+1], 8]}, lf (y): {dataset[footsteps[idx], 9]}, {dataset[footsteps[idx+1], 9]}.')
                print(f'lf displacement: {(dataset[footsteps[idx+1], 8] - dataset[footsteps[idx], 8]).tolist()}, {(dataset[footsteps[idx+1], 9] - dataset[footsteps[idx], 9]).tolist()}.\n')
                
                print(f'lh (x): {dataset[footsteps[idx], 11]}, {dataset[footsteps[idx+1], 11]}, lh (y): {dataset[footsteps[idx], 12]}, {dataset[footsteps[idx+1], 12]}.')
                print(f'lh displacement: {(dataset[footsteps[idx+1], 11] - dataset[footsteps[idx], 11]).tolist()}, {(dataset[footsteps[idx+1], 12] - dataset[footsteps[idx], 12]).tolist()}.\n')
                
                print(f'rf (x): {dataset[footsteps[idx], 14]}, {dataset[footsteps[idx+1], 14]}, rf (y): {dataset[footsteps[idx], 15]}, {dataset[footsteps[idx+1], 15]}.')
                print(f'rf displacement: {(dataset[footsteps[idx+1], 14] - dataset[footsteps[idx], 14]).tolist()}, {(dataset[footsteps[idx+1], 15] - dataset[footsteps[idx], 15]).tolist()}.\n')
                
                print(f'rh (x): {dataset[footsteps[idx], 17]}, {dataset[footsteps[idx+1], 17]}, rh (y): {dataset[footsteps[idx], 18]}, {dataset[footsteps[idx+1], 18]}.')
                print(f'rh displacement: {(dataset[footsteps[idx+1], 17] - dataset[footsteps[idx], 17]).tolist()}, {(dataset[footsteps[idx+1], 18] - dataset[footsteps[idx], 18]).tolist()}.\n')
        
                # Feet displacements
                lf_x_displacement = dataset[footsteps[idx+1], 8] - dataset[footsteps[idx], 8]
                lf_y_displacement = dataset[footsteps[idx+1], 9] - dataset[footsteps[idx], 9]
                lh_x_displacement = dataset[footsteps[idx+1], 11] - dataset[footsteps[idx], 11]
                lh_y_displacement = dataset[footsteps[idx+1], 12] - dataset[footsteps[idx], 12]
                rf_x_displacement = dataset[footsteps[idx+1], 14] - dataset[footsteps[idx], 14]
                rf_y_displacement = dataset[footsteps[idx+1], 15] - dataset[footsteps[idx], 15]
                rh_x_displacement = dataset[footsteps[idx+1], 17] - dataset[footsteps[idx], 17]
                rh_y_displacement = dataset[footsteps[idx+1], 18] - dataset[footsteps[idx], 18]
                
                # Support foot base displacement
                support_base_displacement = [0, 0]
                if contacts[idx, 1]:
                    support_base_displacement[0] = -lf_x_displacement
                    support_base_displacement[1] = -lf_y_displacement
                else:
                    support_base_displacement[0] = -rf_x_displacement
                    support_base_displacement[1] = -rf_y_displacement
                
                prev_yaw = curh_yaw
                    
                print(f'\nBase displacement (CoM): {support_base_displacement}.\n')
                    
                x_0 = np.array([dataset[footstep, 8], 
                                dataset[footstep, 11],
                                dataset[footstep, 14], 
                                dataset[footstep, 17]])
                y_0 = np.array([dataset[footstep, 9], 
                                dataset[footstep, 12],
                                dataset[footstep, 15], 
                                dataset[footstep, 18]])
                
                """
                x_1 = np.array([dataset[footsteps[idx+1], 7], 
                                dataset[footsteps[idx+1], 10],
                                dataset[footsteps[idx+1], 13], 
                                dataset[footsteps[idx+1], 16]])
                y_1 = np.array([dataset[footsteps[idx+1], 8], 
                                dataset[footsteps[idx+1], 11],
                                dataset[footsteps[idx+1], 14], 
                                dataset[footsteps[idx+1], 17]])
                """
                
                x_1 = np.array([dataset[footstep, 8] + lf_x_displacement, 
                                dataset[footstep, 11] + rf_x_displacement,
                                dataset[footstep, 14] + lh_x_displacement, 
                                dataset[footstep, 17] + rh_x_displacement])
                y_1 = np.array([dataset[footstep, 9] + lf_y_displacement, 
                                dataset[footstep, 12] + rf_y_displacement,
                                dataset[footstep, 15] + lh_y_displacement, 
                                dataset[footstep, 18] + rh_y_displacement])
                
                #axes[0].scatter(x_0, y_0, c= 'b',marker='o')
                axes[0].scatter(x_0, y_0, c= 'm',marker='o')
                axes[0].scatter(0, 0, c= 'g', marker='^')
                axes[0].scatter(base_displacement[0], base_displacement[1], c= 'y', marker='^')
                axes[0].scatter(support_base_displacement[0], support_base_displacement[1], c= 'r', marker='^')
                
                axes[1].scatter(x_1, y_1, c= 'r', marker='o')
                axes[1].scatter(x_1, y_1, c= 'c', marker='o')
                
                plt.show()
                
#visualize_absolute_foostep_sizes(motion, footsteps_fwd)

# %% [markdown]
# ### Forward motion

# %%
anim = visualize_animated_footsteps(motion, footsteps_fwd, "bo")
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1160                         frame_number += 1
# -> 1161                 writer.grab_frame(**savefig_kwargs)
#    1162
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     363         self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 364                          dpi=self.dpi, **savefig_kwargs)
#     365
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args)
#     452     def print_raw(self, filename_or_obj, *args):
# --> 453         FigureCanvasAgg.draw(self)
#     454         renderer = self.get_renderer()
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     460             for axis in self._get_axis_list():
# --> 461                 axis.draw(renderer)
#     462
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axis3d.py in draw(self, renderer)
#     396                 info['tick']['linewidth'][tick._major])
# --> 397             tick.draw(renderer)
#     398
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer)
#     290                        self.label1, self.label2]:
# --> 291             artist.draw(renderer)
#     292         renderer.close_group(self.__name__)
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/text.py in draw(self, renderer)
#     728                                            textobj._fontproperties, angle,
# --> 729                                            ismath=ismath, mtext=mtext)
#     730
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     194         flags = get_hinting_flag()
# --> 195         font = self._get_agg_font(prop)
#     196
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in _get_agg_font(self, prop)
#     272         fname = findfont(prop)
# --> 273         font = get_font(fname)
#     274
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/font_manager.py in get_font(filename, hinting_factor)
#    1413     # single font is selected using two different relative paths.
# -> 1414     filename = os.path.realpath(filename)
#    1415     if hinting_factor is None:
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/posixpath.py in realpath(filename)
#     395     path, ok = _joinrealpath(filename[:0], filename, {})
# --> 396     return abspath(path)
#     397
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/posixpath.py in abspath(path)
#     384         path = join(cwd, path)
# --> 385     return normpath(path)
#     386
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/posixpath.py in normpath(path)
#     358         initial_slashes = 2
# --> 359     comps = path.split(sep)
#     360     new_comps = []
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-39-191e0fe01c38> in <module>
#       1 anim = visualize_animated_footsteps(motion, footsteps_fwd, "bo")
# ----> 2 HTML(anim.to_html5_video())
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1334                                 bitrate=mpl.rcParams['animation.bitrate'],
#    1335                                 fps=1000. / self._interval)
# -> 1336                 self.save(str(path), writer=writer)
#    1337                 # Now open and base64 encode.
#    1338                 vid64 = base64.encodebytes(path.read_bytes())
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1159                         progress_callback(frame_number, total_frames)
#    1160                         frame_number += 1
# -> 1161                 writer.grab_frame(**savefig_kwargs)
#    1162
#    1163     def _step(self, *args):
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/animation.py in finish(self)
#     352     def finish(self):
#     353         """Finish any processing for writing the movie."""
# --> 354         self.cleanup()
#     355
#     356     def grab_frame(self, **savefig_kwargs):
#
# ~/miniconda3/envs/pytorch-env/lib/python3.6/site-packages/matplotlib/animation.py in cleanup(self)
#     389         if self._proc.returncode:
#     390             raise subprocess.CalledProcessError(
# --> 391                 self._proc.returncode, self._proc.args, out, err)
#     392
#     393     @classmethod
#
# CalledProcessError: Command '['/usr/bin/ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '432x288', '-pix_fmt', 'rgba', '-r', '5.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmpj_ruxw3q/temp.m4v']' returned non-zero exit status 255.

# %% [markdown]
# ### Side motion (right)

# %%
anim = visualize_animated_footsteps(motion, footsteps_side_right, "bo")
HTML(anim.to_html5_video())

# %% [markdown]
# ### Side motion (left)

# %%
anim = visualize_animated_footsteps(motion, footsteps_side_left, "bo")
HTML(anim.to_html5_video())

# %% [markdown]
# ### Rotation (clockwise)

# %%
anim = visualize_animated_footsteps(motion, footsteps_clock, "bo")
HTML(anim.to_html5_video())

# %% [markdown]
# ### Rotation (counter clockwise)

# %%
anim = visualize_animated_footsteps(motion, footsteps_count, "bo")
HTML(anim.to_html5_video())

# %% [markdown]
# # Dataset Preparation

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
def relative_footstep_prediction_dataset_absolute(dataset, footsteps, debug=False):
    # Footsteps sizes
    inputs = []
    labels = []
    
    for idx, footstep in enumerate(footsteps):
        if idx > 0:
            # Compute time difference between
            # curhent and next footsteps
            time_difference = abs(dataset[footsteps[idx], 0] - dataset[footsteps[idx-1], 0])
            
            if time_difference < 0.5:
                fl_moving = contacts[footsteps[idx], 0]
                fr_moving = contacts[footsteps[idx], 1]
                rl_moving = contacts[footsteps[idx], 2]
                rr_moving = contacts[footsteps[idx], 3]
                
                if debug:
                    print("Time difference: ", time_difference)
                    print("Footstep timestamp: ", dataset[footstep, 0])
                    print(f'lf moving: {fl_moving}. rf moving: {fr_moving}')
                    print(f'lh moving: {rl_moving}. rh moving: {rr_moving}')

                if (not fr_moving != fl_moving or not fr_moving == rl_moving or not fl_moving == rr_moving):
                    print("Exception")
                    print("Time difference: ", time_difference)
                    #print("Footstep timestamp: ", dataset[footstep, 0])
                    print(f'fl moving: {fl_moving}. fr moving: {fr_moving}')
                    print(f'rl moving: {rl_moving}. rr moving: {rr_moving}')
                    continue
                
                assert fr_moving == rl_moving
                assert rr_moving == fl_moving
                assert fr_moving != fl_moving
            
                inputs.append(dataset[footsteps[idx-1], 1:4].tolist() + 
                              dataset[footsteps[idx-1], 51:57].tolist() + 
                              dataset[footsteps[idx-1], 8:20].tolist() + 
                              contacts[footsteps[idx], :].tolist() + 
                              dataset[footsteps[idx], 1:4].tolist() +
                              dataset[footsteps[idx-1], 44:46].tolist() +
                              dataset[footsteps[idx], 44:46].tolist())
                
                if fr_moving:
                    labels.append([(dataset[footsteps[idx], 44] + dataset[footsteps[idx], 11]) - (dataset[footsteps[idx-1], 44] + dataset[footsteps[idx-1], 11]),
                                  (dataset[footsteps[idx], 45] + dataset[footsteps[idx], 12]) - (dataset[footsteps[idx-1], 45] + dataset[footsteps[idx-1], 12]),
                                  (dataset[footsteps[idx], 44] + dataset[footsteps[idx], 14]) - (dataset[footsteps[idx-1], 44] + dataset[footsteps[idx-1], 14]),
                                  (dataset[footsteps[idx], 45] + dataset[footsteps[idx], 15]) - (dataset[footsteps[idx-1], 45] + dataset[footsteps[idx-1], 15])])
                else:
                    labels.append([(dataset[footsteps[idx], 44] + dataset[footsteps[idx], 8]) - (dataset[footsteps[idx-1], 44] + dataset[footsteps[idx-1], 8]),
                                  (dataset[footsteps[idx], 45] + dataset[footsteps[idx], 9]) - (dataset[footsteps[idx-1], 45] + dataset[footsteps[idx-1], 9]),
                                  (dataset[footsteps[idx], 44] + dataset[footsteps[idx], 17]) - (dataset[footsteps[idx-1], 44] + dataset[footsteps[idx-1], 17]),
                                  (dataset[footsteps[idx], 45] + dataset[footsteps[idx], 18]) - (dataset[footsteps[idx-1], 45] + dataset[footsteps[idx-1], 18])])
                
    # Convert to numpy array
    inputs_numpy = np.array(inputs)
    labels_numpy = np.array(labels)
    
    return inputs_numpy, labels_numpy

X_relative_footsteps_fwd, Y_relative_footsteps_fwd = relative_footstep_prediction_dataset_absolute(motion, footsteps_fwd)
#X_relative_footsteps_bwd, Y_relative_footsteps_bwd = relative_footstep_prediction_dataset(motion, footsteps_bwd)
X_relative_footsteps_clock, Y_relative_footsteps_clock = relative_footstep_prediction_dataset_absolute(motion, footsteps_clock)
X_relative_footsteps_count, Y_relative_footsteps_count = relative_footstep_prediction_dataset_absolute(motion, footsteps_count)
X_relative_footsteps_left, Y_relative_footsteps_left = relative_footstep_prediction_dataset_absolute(motion, footsteps_side_left)
X_relative_footsteps_right, Y_relative_footsteps_right = relative_footstep_prediction_dataset_absolute(motion, footsteps_side_right)

# Stack datasets
X_relative_footsteps_continuous_absolute = np.concatenate((X_relative_footsteps_fwd, X_relative_footsteps_clock, X_relative_footsteps_count, X_relative_footsteps_left, X_relative_footsteps_right))
Y_relative_footsteps_continuous_absolute = np.concatenate((Y_relative_footsteps_fwd, Y_relative_footsteps_clock, Y_relative_footsteps_count, Y_relative_footsteps_left, Y_relative_footsteps_right))

# Log
print(X_relative_footsteps_continuous_absolute.shape)
print(Y_relative_footsteps_continuous_absolute.shape)
# Out:
# (10027, 32)
# (10027, 4)

# %%
# %store X_relative_footsteps_continuous_absolute
# %store Y_relative_footsteps_continuous_absolute
# Out:
# Stored 'X_relative_footsteps_continuous_absolute' (ndarray)
# Stored 'Y_relative_footsteps_continuous_absolute' (ndarray)

# %%
min(Y_relative_footsteps_fwd[:, 0])
# Out:
# 0.023456837601111502
